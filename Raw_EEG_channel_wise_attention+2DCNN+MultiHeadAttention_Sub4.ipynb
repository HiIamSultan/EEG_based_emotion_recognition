# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import pickle as pkl
from tensorflow import keras
import tensorflow.keras.backend as K
from keras.models import Sequential,Model
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Flatten, Input, Reshape, BatchNormalization, Bidirectional, LSTM, Multiply, Activation, Normalization, TimeDistributed
from keras.layers import Conv3D, Conv2D, Conv1D, MaxPool3D, MaxPool2D, MaxPool1D, AvgPool3D, AvgPool2D, AvgPool1D, GlobalMaxPool3D, Attention, Subtract
from keras.layers import GlobalMaxPool2D, GlobalMaxPool1D, SpatialDropout3D, SpatialDropout2D, SpatialDropout1D, GlobalAvgPool3D, MultiHeadAttention
from keras.layers import GlobalAvgPool2D, GlobalAvgPool1D, SeparableConv2D, SeparableConv1D, Add, Concatenate, LeakyReLU, ELU, Activation, PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight
import gc

# %% [markdown]
# # **Data Loading**

# %%
from google.colab import drive
drive.mount('/content/drive/')
gc.collect()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# 59

# %%
input_path='/content/drive/MyDrive/data_preprocessed_python/'

# %%
def baseline_remove(XR):
  XT = XR[:, 384:]
  XB_ = (XR[:, :1*128] + XR[:, 1*128:2*128] + XR[:, 2*128:3*128])/3.0
  for i in range(60):
    XT[:, i*128:(i+1)*128] = XT[:, i*128:(i+1)*128] - XB_
  return XT

# %%
new_channels = [0,1,18,2,3,5,4,23,6,7,9,8,15,10,11,12,14,13,
 16,17,18,19,20,22,21,23,24,25,27,26,15,28,29,30,14,31]

# %%
eeg_signal = []
valence = []
arousal = []
window_size = 256
no_channels = 32
no_new_channels = len(new_channels)
no_videos = 40
Trsld = 5

for person in range(4,5):
  print('Person No.' + str(person))
  
  
  # EEG files address
  if person < 10 :
    address = input_path+'s0'+str(person)+'.dat'
  else :
    address = input_path+'s'+str(person)+'.dat'

  with open(address, 'rb') as file:
    data = pkl.load(file, encoding = 'latin1')

  eeg = data['data']
  label = data['labels']
  
  # Assigning classes
  label[label<Trsld] = 0
  label[label>=Trsld] = 1

  val = label.T[0] # Valence label
  aro = label.T[1] # Arousal label

  del data, label
  # Iterating through 40 vidoes/trials
  for i in range(no_videos):
    sig = eeg[i][:no_channels, :]
    sig = baseline_remove(sig)
    temp = []
    for j in new_channels:
      temp.append(sig[j, :])
    sig = np.reshape(temp,[no_new_channels,-1])
    # Segmenting into 2 seconds (256 timesteps) windows without overlap
    start = 0
    while start + window_size <=sig.shape[1]:
      eeg_signal.append(sig[:, start:start+window_size])
      valence.append(val[i])
      arousal.append(aro[i])
      start += window_size 
  del eeg, val, aro, sig
eeg_signal = np.reshape(eeg_signal,[-1,no_new_channels,window_size])
data = np.asarray(eeg_signal, dtype = np.float32) # Using 32 bit floating point value to save memory
del eeg_signal
valence = np.asarray(valence, dtype = np.int8)
arousal = np.asarray(arousal, dtype = np.int8)

print(data.shape)
print(valence.shape, valence[valence == 0].shape, valence[valence == 1].shape)
print(arousal.shape, arousal[arousal == 0].shape, arousal[arousal == 1].shape)

valence = np_utils.to_categorical(valence)
arousal = np_utils.to_categorical(arousal)
gc.collect()
# Out:
# Person No.4
# (1200, 36, 256)
# (1200,) (720,) (480,)
# (1200,) (720,) (480,)
# 3576

# %%
def simple_2D_CNN(x): 
  y = AvgPool2D(pool_size=(1,window_size))(x)
  y = Flatten()(y)
  y = Dense(4,activation='tanh') (y)
  y = Dense(no_new_channels,activation='softmax') (y)
  x = Multiply()([x, tf.expand_dims(tf.expand_dims(y, axis=2), axis=2)])
  x1 = Conv2D(filters = 32, kernel_size = (1,16), strides = (1,1), padding = 'same', activation='selu')(x) #above 8 Hz
  x2 = Conv2D(filters = 32, kernel_size = (1,10), strides = (1,1), padding = 'same', activation='selu')(x) #above 12.8 Hz
  x3 = Conv2D(filters = 32, kernel_size = (1,6), strides = (1,1), padding = 'same', activation='selu')(x) #above 21.3 Hz
  x1 = Subtract()([x1, x2]) #above 8 Hz and below 12.8 Hz
  x1 = MaxPool2D(pool_size=(1,2))(x1) #downsampling by 2
  x1 = Conv2D(filters = 32, kernel_size = (1,16), strides = (1,1), padding = 'same', activation='selu')(x1)
  x1 = MaxPool2D(pool_size=(1,2))(x1)
  x1 = Conv2D(filters = 32, kernel_size = (1,16), strides = (1,1), padding = 'same', activation='selu')(x1)
  x1 = MaxPool2D(pool_size=(1,2))(x1)
  x2 = Subtract()([x2, x3]) #above 12.8 Hz and below 21.3 Hz
  x2 = MaxPool2D(pool_size=(1,2))(x2)
  x2 = Conv2D(filters = 32, kernel_size = (1,10), strides = (1,1), padding = 'same', activation='selu')(x2)
  x2 = MaxPool2D(pool_size=(1,2))(x2)
  x2 = Conv2D(filters = 32, kernel_size = (1,10), strides = (1,1), padding = 'same', activation='selu')(x2)
  x2 = MaxPool2D(pool_size=(1,2))(x2)
  x = Concatenate(axis=3)([x1, x2])
  x = Dropout(0.1)(x)
  x1 = Conv2D(filters = 64, kernel_size = (2,4), strides = (2,1), padding = 'same', activation='selu')(x)
  x1 = Conv2D(filters = 64, kernel_size = (3,4), strides = (3,1), padding = 'same', activation='selu')(x1)
  x1 = Conv2D(filters = 64, kernel_size = (3,4), strides = (3,1), padding = 'same', activation='selu')(x1)
  x1 = MaxPool2D(pool_size=(1,2))(x1)
  x2 = Conv2D(filters = 64, kernel_size = (3,4), strides = (3,1), padding = 'same', activation='selu')(x)
  x2 = Conv2D(filters = 64, kernel_size = (2,4), strides = (2,1), padding = 'same', activation='selu')(x2)
  x2 = Conv2D(filters = 64, kernel_size = (3,4), strides = (3,1), padding = 'same', activation='selu')(x2)
  x2 = MaxPool2D(pool_size=(1,2))(x2)
  x3 = Conv2D(filters = 64, kernel_size = (6,4), strides = (6,1), padding = 'same', activation='selu')(x)
  x3 = Conv2D(filters = 64, kernel_size = (3,4), strides = (3,1), padding = 'same', activation='selu')(x3)
  x3 = MaxPool2D(pool_size=(1,2))(x3)
  x4 = Conv2D(filters = 64, kernel_size = (9,4), strides = (9,1), padding = 'same', activation='selu')(x)
  x4 = Conv2D(filters = 64, kernel_size = (2,4), strides = (2,1), padding = 'same', activation='selu')(x4)
  x4 = MaxPool2D(pool_size=(1,2))(x4)
  x5 = Conv2D(filters = 64, kernel_size = (18,4), strides = (18,1), padding = 'same', activation='selu')(x)
  x5 = MaxPool2D(pool_size=(1,2))(x5)
  x = Concatenate(axis=3)([x1, x2, x3, x4, x5])
  x = Dropout(0.1)(x)
  x = Conv2D(filters = x.shape[3], kernel_size = (2,2), strides = (2,1), padding = 'same', activation='selu')(x)
  x = GlobalAvgPool2D()(x)
  x = Reshape((1, x.shape[1]))(x)
  y = MultiHeadAttention(num_heads=2, key_dim=2)(x, x)
  y = Activation('softmax')(y)
  x = Multiply()([x, y])
  x = Flatten()(x)
  x = Dense(128, activation='tanh')(x)
  x = Dropout(0.1)(x)
  x = Dense(32, activation='relu')(x)
  x = Dropout(0.1)(x)
  x = Dense(2, activation='softmax')(x)
  return x

def get_model(): 
  input_shape = (data.shape[1], data.shape[2], 1) 
  a = Input(input_shape) 
  out = simple_2D_CNN(a) 
  model = Model(a, out) 
  opt = keras.optimizers.Adam(learning_rate=1e-04) 
  model.compile(loss=keras.losses.categorical_crossentropy, metrics=["accuracy"], optimizer=opt) 
  return model 
model = get_model() 
model.summary()
# Out:
# Model: "model_51"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_52 (InputLayer)          [(None, 36, 256, 1)  0           []
#                                 ]
#
#  average_pooling2d_51 (AverageP  (None, 36, 1, 1)    0           ['input_52[0][0]']
#  ooling2D)
#
#  flatten_51 (Flatten)           (None, 36)           0           ['average_pooling2d_51[0][0]']
#
#  dense_255 (Dense)              (None, 4)            148         ['flatten_51[0][0]']
#
#  dense_256 (Dense)              (None, 36)           180         ['dense_255[0][0]']
#
#  tf.expand_dims_102 (TFOpLambda  (None, 36, 1)       0           ['dense_256[0][0]']
#  )
#
#  tf.expand_dims_103 (TFOpLambda  (None, 36, 1, 1)    0           ['tf.expand_dims_102[0][0]']
#  )
#
#  multiply_51 (Multiply)         (None, 36, 256, 1)   0           ['input_52[0][0]',
#                                                                   'tf.expand_dims_103[0][0]']
#
#  conv2d_969 (Conv2D)            (None, 36, 256, 32)  544         ['multiply_51[0][0]']
#
#  conv2d_970 (Conv2D)            (None, 36, 256, 32)  352         ['multiply_51[0][0]']
#
#  conv2d_971 (Conv2D)            (None, 36, 256, 32)  224         ['multiply_51[0][0]']
#
#  subtract_102 (Subtract)        (None, 36, 256, 32)  0           ['conv2d_969[0][0]',
#                                                                   'conv2d_970[0][0]']
#
#  subtract_103 (Subtract)        (None, 36, 256, 32)  0           ['conv2d_970[0][0]',
#                                                                   'conv2d_971[0][0]']
#
#  max_pooling2d_561 (MaxPooling2  (None, 36, 128, 32)  0          ['subtract_102[0][0]']
#  D)
#
#  max_pooling2d_564 (MaxPooling2  (None, 36, 128, 32)  0          ['subtract_103[0][0]']
#  D)
#
#  conv2d_972 (Conv2D)            (None, 36, 128, 32)  16416       ['max_pooling2d_561[0][0]']
#
#  conv2d_974 (Conv2D)            (None, 36, 128, 32)  10272       ['max_pooling2d_564[0][0]']
#
#  max_pooling2d_562 (MaxPooling2  (None, 36, 64, 32)  0           ['conv2d_972[0][0]']
#  D)
#
#  max_pooling2d_565 (MaxPooling2  (None, 36, 64, 32)  0           ['conv2d_974[0][0]']
#  D)
#
#  conv2d_973 (Conv2D)            (None, 36, 64, 32)   16416       ['max_pooling2d_562[0][0]']
#
#  conv2d_975 (Conv2D)            (None, 36, 64, 32)   10272       ['max_pooling2d_565[0][0]']
#
#  max_pooling2d_563 (MaxPooling2  (None, 36, 32, 32)  0           ['conv2d_973[0][0]']
#  D)
#
#  max_pooling2d_566 (MaxPooling2  (None, 36, 32, 32)  0           ['conv2d_975[0][0]']
#  D)
#
#  concatenate_102 (Concatenate)  (None, 36, 32, 64)   0           ['max_pooling2d_563[0][0]',
#                                                                   'max_pooling2d_566[0][0]']
#
#  dropout_204 (Dropout)          (None, 36, 32, 64)   0           ['concatenate_102[0][0]']
#
#  conv2d_976 (Conv2D)            (None, 18, 32, 64)   32832       ['dropout_204[0][0]']
#
#  conv2d_979 (Conv2D)            (None, 12, 32, 64)   49216       ['dropout_204[0][0]']
#
#  conv2d_977 (Conv2D)            (None, 6, 32, 64)    49216       ['conv2d_976[0][0]']
#
#  conv2d_980 (Conv2D)            (None, 6, 32, 64)    32832       ['conv2d_979[0][0]']
#
#  conv2d_982 (Conv2D)            (None, 6, 32, 64)    98368       ['dropout_204[0][0]']
#
#  conv2d_984 (Conv2D)            (None, 4, 32, 64)    147520      ['dropout_204[0][0]']
#
#  conv2d_978 (Conv2D)            (None, 2, 32, 64)    49216       ['conv2d_977[0][0]']
#
#  conv2d_981 (Conv2D)            (None, 2, 32, 64)    49216       ['conv2d_980[0][0]']
#
#  conv2d_983 (Conv2D)            (None, 2, 32, 64)    49216       ['conv2d_982[0][0]']
#
#  conv2d_985 (Conv2D)            (None, 2, 32, 64)    32832       ['conv2d_984[0][0]']
#
#  conv2d_986 (Conv2D)            (None, 2, 32, 64)    294976      ['dropout_204[0][0]']
#
#  max_pooling2d_567 (MaxPooling2  (None, 2, 16, 64)   0           ['conv2d_978[0][0]']
#  D)
#
#  max_pooling2d_568 (MaxPooling2  (None, 2, 16, 64)   0           ['conv2d_981[0][0]']
#  D)
#
#  max_pooling2d_569 (MaxPooling2  (None, 2, 16, 64)   0           ['conv2d_983[0][0]']
#  D)
#
#  max_pooling2d_570 (MaxPooling2  (None, 2, 16, 64)   0           ['conv2d_985[0][0]']
#  D)
#
#  max_pooling2d_571 (MaxPooling2  (None, 2, 16, 64)   0           ['conv2d_986[0][0]']
#  D)
#
#  concatenate_103 (Concatenate)  (None, 2, 16, 320)   0           ['max_pooling2d_567[0][0]',
#                                                                   'max_pooling2d_568[0][0]',
#                                                                   'max_pooling2d_569[0][0]',
#                                                                   'max_pooling2d_570[0][0]',
#                                                                   'max_pooling2d_571[0][0]']
#
#  dropout_205 (Dropout)          (None, 2, 16, 320)   0           ['concatenate_103[0][0]']
#
#  conv2d_987 (Conv2D)            (None, 1, 16, 320)   409920      ['dropout_205[0][0]']
#
#  global_average_pooling2d_51 (G  (None, 320)         0           ['conv2d_987[0][0]']
#  lobalAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 320)       0           ['global_average_pooling2d_51[0][
#                                                                  0]']
#
#  multi_head_attention (MultiHea  (None, 1, 320)      5452        ['reshape[0][0]',
#  dAttention)                                                      'reshape[0][0]']
#
#  activation (Activation)        (None, 1, 320)       0           ['multi_head_attention[0][0]']
#
#  multiply_52 (Multiply)         (None, 1, 320)       0           ['reshape[0][0]',
#                                                                   'activation[0][0]']
#
#  flatten_52 (Flatten)           (None, 320)          0           ['multiply_52[0][0]']
#
#  dense_257 (Dense)              (None, 128)          41088       ['flatten_52[0][0]']
#
#  dropout_206 (Dropout)          (None, 128)          0           ['dense_257[0][0]']
#
#  dense_258 (Dense)              (None, 32)           4128        ['dropout_206[0][0]']
#
#  dropout_207 (Dropout)          (None, 32)           0           ['dense_258[0][0]']
#
#  dense_259 (Dense)              (None, 2)            66          ['dropout_207[0][0]']
#
# ==================================================================================================
# Total params: 1,400,918
# Trainable params: 1,400,918
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
batch_size = 64
epochs = 100
kfold = KFold(n_splits=10, random_state=1, shuffle=True)
gc.collect()
# Out:
# 16018

# %%
def call_class_weights(yt):
  y_integers = np.argmax(yt, axis=1)
  class_weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(y_integers), y = y_integers)
  d_class_weights = dict(enumerate(class_weights))
  return d_class_weights

# %% [markdown]
# # **Valence**

# %%
#valence
X_train, x_test, Y_train, y_test = train_test_split(data, valence, test_size=0.1, random_state=4)
print(X_train.shape,x_test.shape,Y_train.shape,y_test.shape)
# Out:
# (1080, 36, 256) (120, 36, 256) (1080, 2) (120, 2)

# %%
val_res = {'accuracy': [], 'f1_score': [], 'confusion_matrix': []}
foldNum=0
#model = get_model()
for train_index, val_index in kfold.split(X_train, Y_train):
  foldNum = foldNum + 1
  model = get_model()
  print("Results for fold",foldNum)
  x_train, x_val = X_train[train_index], X_train[val_index]
  y_train, y_val = Y_train[train_index], Y_train[val_index]
  class_weight = call_class_weights(y_train)
  history = model.fit(x_train, y_train, epochs=epochs, class_weight=class_weight, batch_size=batch_size, verbose=1, validation_data=(x_val, y_val),shuffle=True)
  acc = model.evaluate(x_test, y_test)
  print(acc)
  val_res['accuracy'].append(acc)
  pred = model.predict(x_test)
  f1scr = f1_score(y_test.argmax(1), pred.argmax(1), average='macro')
  print(f1scr)
  pd.DataFrame(history.history).plot(figsize=(8,5))
  plt.show()
  val_res['f1_score'].append(f1scr)
  val_res['confusion_matrix'].append(confusion_matrix(y_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter
  del x_train, x_val, y_train, y_val, acc, f1scr
  gc.collect()
# Out:
# Results for fold 1
# Epoch 1/100
# 16/16 [==============================] - 4s 134ms/step - loss: 0.6924 - accuracy: 0.4064 - val_loss: 0.6909 - val_accuracy: 0.5926
# Epoch 2/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.6883 - accuracy: 0.5751 - val_loss: 0.6835 - val_accuracy: 0.5833
# Epoch 3/100
# 16/16 [==============================] - 2s 110ms/step - loss: 0.6765 - accuracy: 0.6049 - val_loss: 0.6712 - val_accuracy: 0.5833
# Epoch 4/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.6518 - accuracy: 0.6409 - val_loss: 0.6083 - val_accuracy: 0.7222
# Epoch 5/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.6045 - accuracy: 0.7047 - val_loss: 0.6179 - val_accuracy: 0.6574
# Epoch 6/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.5816 - accuracy: 0.6975 - val_loss: 0.5005 - val_accuracy: 0.8056
# Epoch 7/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.5304 - accuracy: 0.7438 - val_loss: 0.4777 - val_accuracy: 0.7315
# Epoch 8/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.5014 - accuracy: 0.7562 - val_loss: 0.4846 - val_accuracy: 0.7870
# Epoch 9/100
# 16/16 [==============================] - 2s 111ms/step - loss: 0.5046 - accuracy: 0.7716 - val_loss: 0.4766 - val_accuracy: 0.7685
# Epoch 10/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.4842 - accuracy: 0.7716 - val_loss: 0.4691 - val_accuracy: 0.7870
# Epoch 11/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4960 - accuracy: 0.7665 - val_loss: 0.5925 - val_accuracy: 0.6759
# Epoch 12/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.4800 - accuracy: 0.7603 - val_loss: 0.4121 - val_accuracy: 0.8611
# Epoch 13/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4420 - accuracy: 0.8076 - val_loss: 0.3888 - val_accuracy: 0.8241
# Epoch 14/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4279 - accuracy: 0.7942 - val_loss: 0.3835 - val_accuracy: 0.8241
# Epoch 15/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4146 - accuracy: 0.8138 - val_loss: 0.4071 - val_accuracy: 0.8241
# Epoch 16/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3976 - accuracy: 0.8220 - val_loss: 0.3848 - val_accuracy: 0.8333
# Epoch 17/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.4051 - accuracy: 0.8148 - val_loss: 0.4270 - val_accuracy: 0.7870
# Epoch 18/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3827 - accuracy: 0.8117 - val_loss: 0.3735 - val_accuracy: 0.8426
# Epoch 19/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3666 - accuracy: 0.8169 - val_loss: 0.3772 - val_accuracy: 0.8519
# Epoch 20/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3708 - accuracy: 0.8272 - val_loss: 0.3906 - val_accuracy: 0.8333
# Epoch 21/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3432 - accuracy: 0.8529 - val_loss: 0.4190 - val_accuracy: 0.7778
# Epoch 22/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3109 - accuracy: 0.8663 - val_loss: 0.4222 - val_accuracy: 0.7685
# Epoch 23/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3057 - accuracy: 0.8549 - val_loss: 0.4473 - val_accuracy: 0.8056
# Epoch 24/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2803 - accuracy: 0.8714 - val_loss: 0.3921 - val_accuracy: 0.7778
# Epoch 25/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2652 - accuracy: 0.8786 - val_loss: 0.3687 - val_accuracy: 0.8333
# Epoch 26/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2457 - accuracy: 0.8848 - val_loss: 0.4888 - val_accuracy: 0.8241
# Epoch 27/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2884 - accuracy: 0.8683 - val_loss: 0.3503 - val_accuracy: 0.8704
# Epoch 28/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2385 - accuracy: 0.8992 - val_loss: 0.4096 - val_accuracy: 0.8148
# Epoch 29/100
# 16/16 [==============================] - 2s 116ms/step - loss: 0.1984 - accuracy: 0.9259 - val_loss: 0.6648 - val_accuracy: 0.7500
# Epoch 30/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2230 - accuracy: 0.9053 - val_loss: 0.4446 - val_accuracy: 0.8241
# Epoch 31/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.2122 - accuracy: 0.9218 - val_loss: 0.6087 - val_accuracy: 0.7778
# Epoch 32/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.1846 - accuracy: 0.9259 - val_loss: 0.3577 - val_accuracy: 0.8426
# Epoch 33/100
# 16/16 [==============================] - 2s 116ms/step - loss: 0.2158 - accuracy: 0.9084 - val_loss: 0.3474 - val_accuracy: 0.8611
# Epoch 34/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.1476 - accuracy: 0.9444 - val_loss: 0.4008 - val_accuracy: 0.8426
# Epoch 35/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.1321 - accuracy: 0.9434 - val_loss: 0.3501 - val_accuracy: 0.8704
# Epoch 36/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0904 - accuracy: 0.9702 - val_loss: 0.5012 - val_accuracy: 0.8241
# Epoch 37/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.1145 - accuracy: 0.9568 - val_loss: 0.2901 - val_accuracy: 0.8704
# Epoch 38/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0704 - accuracy: 0.9774 - val_loss: 0.3993 - val_accuracy: 0.8889
# Epoch 39/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0518 - accuracy: 0.9815 - val_loss: 0.3435 - val_accuracy: 0.9074
# Epoch 40/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0443 - accuracy: 0.9866 - val_loss: 0.5666 - val_accuracy: 0.8519
# Epoch 41/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0541 - accuracy: 0.9774 - val_loss: 0.5183 - val_accuracy: 0.8796
# Epoch 42/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0317 - accuracy: 0.9887 - val_loss: 0.4490 - val_accuracy: 0.8796
# Epoch 43/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0176 - accuracy: 0.9969 - val_loss: 0.5169 - val_accuracy: 0.8796
# Epoch 44/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0352 - accuracy: 0.9846 - val_loss: 0.6084 - val_accuracy: 0.8889
# Epoch 45/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0461 - accuracy: 0.9815 - val_loss: 0.5480 - val_accuracy: 0.8519
# Epoch 46/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0288 - accuracy: 0.9907 - val_loss: 0.6445 - val_accuracy: 0.8426
# Epoch 47/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0887 - accuracy: 0.9702 - val_loss: 0.3489 - val_accuracy: 0.9074
# Epoch 48/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0737 - accuracy: 0.9774 - val_loss: 0.3068 - val_accuracy: 0.8981
# Epoch 49/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0311 - accuracy: 0.9918 - val_loss: 0.3023 - val_accuracy: 0.9074
# Epoch 50/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0197 - accuracy: 0.9959 - val_loss: 0.4175 - val_accuracy: 0.8704
# Epoch 51/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0208 - accuracy: 0.9949 - val_loss: 0.3715 - val_accuracy: 0.8889
# Epoch 52/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.8889
# Epoch 53/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4093 - val_accuracy: 0.8889
# Epoch 54/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4095 - val_accuracy: 0.8889
# Epoch 55/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.8889
# Epoch 56/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4448 - val_accuracy: 0.8981
# Epoch 57/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4289 - val_accuracy: 0.8889
# Epoch 58/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4305 - val_accuracy: 0.8889
# Epoch 59/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4458 - val_accuracy: 0.8981
# Epoch 60/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.8981
# Epoch 61/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.8981
# Epoch 62/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.8889
# Epoch 63/100
# 16/16 [==============================] - 2s 113ms/step - loss: 9.5460e-04 - accuracy: 1.0000 - val_loss: 0.4736 - val_accuracy: 0.8981
# Epoch 64/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.7004 - val_accuracy: 0.8611
# Epoch 65/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0034 - accuracy: 0.9979 - val_loss: 0.6250 - val_accuracy: 0.8704
# Epoch 66/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0322 - accuracy: 0.9866 - val_loss: 1.1951 - val_accuracy: 0.8333
# Epoch 67/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.2379 - accuracy: 0.9403 - val_loss: 1.6054 - val_accuracy: 0.6944
# Epoch 68/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2047 - accuracy: 0.9311 - val_loss: 0.2602 - val_accuracy: 0.8889
# Epoch 69/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0766 - accuracy: 0.9887 - val_loss: 0.2702 - val_accuracy: 0.9074
# Epoch 70/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0260 - accuracy: 0.9979 - val_loss: 0.3190 - val_accuracy: 0.8981
# Epoch 71/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.3451 - val_accuracy: 0.8981
# Epoch 72/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.3932 - val_accuracy: 0.9074
# Epoch 73/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0114 - accuracy: 0.9979 - val_loss: 0.4021 - val_accuracy: 0.8981
# Epoch 74/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.3383 - val_accuracy: 0.8981
# Epoch 75/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3488 - val_accuracy: 0.8981
# Epoch 76/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3612 - val_accuracy: 0.8889
# Epoch 77/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3660 - val_accuracy: 0.8796
# Epoch 78/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3850 - val_accuracy: 0.8981
# Epoch 79/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3836 - val_accuracy: 0.8889
# Epoch 80/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.8981
# Epoch 81/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.4447 - val_accuracy: 0.8889
# Epoch 82/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4220 - val_accuracy: 0.8796
# Epoch 83/100
# 16/16 [==============================] - 2s 114ms/step - loss: 9.3166e-04 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.8796
# Epoch 84/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4397 - val_accuracy: 0.8796
# Epoch 85/100
# 16/16 [==============================] - 2s 114ms/step - loss: 8.4968e-04 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.8796
# Epoch 86/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.8889
# Epoch 87/100
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.8796
# Epoch 88/100
# 16/16 [==============================] - 2s 114ms/step - loss: 9.7057e-04 - accuracy: 1.0000 - val_loss: 0.4712 - val_accuracy: 0.8889
# Epoch 89/100
# 16/16 [==============================] - 2s 113ms/step - loss: 9.4441e-04 - accuracy: 1.0000 - val_loss: 0.4770 - val_accuracy: 0.8889
# Epoch 90/100
# 16/16 [==============================] - 2s 113ms/step - loss: 5.4854e-04 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8796
# Epoch 91/100
# 16/16 [==============================] - 2s 113ms/step - loss: 5.0406e-04 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8796
# Epoch 92/100
# 16/16 [==============================] - 2s 113ms/step - loss: 5.1213e-04 - accuracy: 1.0000 - val_loss: 0.4875 - val_accuracy: 0.8796
# Epoch 93/100
# 16/16 [==============================] - 2s 113ms/step - loss: 5.0784e-04 - accuracy: 1.0000 - val_loss: 0.4957 - val_accuracy: 0.8796
# Epoch 94/100
# 16/16 [==============================] - 2s 113ms/step - loss: 4.6227e-04 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8796
# Epoch 95/100
# 16/16 [==============================] - 2s 113ms/step - loss: 5.1508e-04 - accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.8796
# Epoch 96/100
# 16/16 [==============================] - 2s 113ms/step - loss: 4.7911e-04 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.8796
# Epoch 97/100
# 16/16 [==============================] - 2s 113ms/step - loss: 4.1493e-04 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.8796
# Epoch 98/100
# 16/16 [==============================] - 2s 113ms/step - loss: 3.8842e-04 - accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 0.8796
# Epoch 99/100
# 16/16 [==============================] - 2s 114ms/step - loss: 4.1226e-04 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.8796
# Epoch 100/100
# 16/16 [==============================] - 2s 114ms/step - loss: 4.3926e-04 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.8796
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6936 - accuracy: 0.9000
# [0.6935611963272095, 0.8999999761581421]
# 0.8933333333333333
# Results for fold 2
# Epoch 1/100
# 16/16 [==============================] - 4s 139ms/step - loss: 0.6928 - accuracy: 0.4496 - val_loss: 0.6890 - val_accuracy: 0.6759
# Epoch 2/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.6875 - accuracy: 0.6533 - val_loss: 0.6762 - val_accuracy: 0.6944
# Epoch 3/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.6759 - accuracy: 0.6656 - val_loss: 0.6667 - val_accuracy: 0.6389
# Epoch 4/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.6440 - accuracy: 0.6564 - val_loss: 0.5747 - val_accuracy: 0.6944
# Epoch 5/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.6060 - accuracy: 0.6708 - val_loss: 0.5766 - val_accuracy: 0.7130
# Epoch 6/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.5773 - accuracy: 0.6996 - val_loss: 0.5294 - val_accuracy: 0.7315
# Epoch 7/100
# 16/16 [==============================] - 2s 112ms/step - loss: 0.5471 - accuracy: 0.7016 - val_loss: 0.4755 - val_accuracy: 0.7778
# Epoch 8/100
# 16/16 [==============================] - 2s 113ms/step - loss: 0.5358 - accuracy: 0.7119 - val_loss: 0.5756 - val_accuracy: 0.7130
# Epoch 9/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.5052 - accuracy: 0.7346 - val_loss: 0.4387 - val_accuracy: 0.7963
# Epoch 10/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.4924 - accuracy: 0.7623 - val_loss: 0.4979 - val_accuracy: 0.7778
# Epoch 11/100
# 16/16 [==============================] - 2s 114ms/step - loss: 0.4665 - accuracy: 0.7767 - val_loss: 0.4539 - val_accuracy: 0.7685
# Epoch 12/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.4553 - accuracy: 0.7875

# %%
#50 epochs
acrc = np.array(val_res['accuracy']).mean(axis=0)
f1scr = np.array(val_res['f1_score']).mean(axis=0)
print("Accuracy  : {}".format(acrc[1]))
print("F1_Score  : {}".format(f1scr))
cmatrix = np.array(val_res['confusion_matrix']).mean(axis=0)
c_matrix = cmatrix/np.sum(cmatrix, axis=1).reshape(2,1)
import seaborn as sns
figure = plt.figure(figsize=(9, 9))
sns.heatmap(c_matrix, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# # **Arousal**

# %%
#arousal
X_train, x_test, Y_train, y_test = train_test_split(data,arousal, test_size=0.1, random_state=4)
print(X_train.shape,x_test.shape,Y_train.shape,y_test.shape)

# %%
val_res = {'accuracy': [], 'f1_score': [], 'confusion_matrix': []}
foldNum=0
#model = get_model()
for train_index, val_index in kfold.split(X_train, Y_train):
  foldNum = foldNum + 1
  model = get_model()
  print("Results for fold",foldNum)
  x_train, x_val = X_train[train_index], X_train[val_index]
  y_train, y_val = Y_train[train_index], Y_train[val_index]
  class_weight = call_class_weights(y_train)
  history = model.fit(x_train, y_train, epochs=epochs, class_weight=class_weight, batch_size=batch_size, verbose=1, validation_data=(x_val, y_val),shuffle=True)
  acc = model.evaluate(x_test, y_test)
  print(acc)
  val_res['accuracy'].append(acc)
  pred = model.predict(x_test)
  f1scr = f1_score(y_test.argmax(1), pred.argmax(1), average='macro')
  print(f1scr)
  pd.DataFrame(history.history).plot(figsize=(8,5))
  plt.show()
  val_res['f1_score'].append(f1scr)
  val_res['confusion_matrix'].append(confusion_matrix(y_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter
  del x_train, x_val, y_train, y_val, acc, f1scr
  gc.collect()

# %%
acrc = np.array(val_res['accuracy']).mean(axis=0)
f1scr = np.array(val_res['f1_score']).mean(axis=0)
print("Accuracy  : {}".format(acrc[1]))
print("F1_Score  : {}".format(f1scr))
cmatrix = np.array(val_res['confusion_matrix']).mean(axis=0)
c_matrix = cmatrix/np.sum(cmatrix, axis=1).reshape(2,1)
import seaborn as sns
figure = plt.figure(figsize=(9, 9))
sns.heatmap(c_matrix, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
