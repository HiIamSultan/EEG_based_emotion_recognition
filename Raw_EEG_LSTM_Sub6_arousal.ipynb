# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import pickle as pkl
from tensorflow import keras
import tensorflow.keras.backend as K
from keras.models import Sequential,Model
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Flatten, Input, Reshape, BatchNormalization, Bidirectional, LSTM, Multiply, Activation, Normalization, TimeDistributed
from keras.layers import Conv3D, Conv2D, Conv1D, MaxPool3D, MaxPool2D, MaxPool1D, AvgPool3D, AvgPool2D, AvgPool1D, GlobalMaxPool3D, Attention, Subtract
from keras.layers import GlobalMaxPool2D, GlobalMaxPool1D, SpatialDropout3D, SpatialDropout2D, SpatialDropout1D, GlobalAvgPool3D, MultiHeadAttention
from keras.layers import GlobalAvgPool2D, GlobalAvgPool1D, SeparableConv2D, SeparableConv1D, Add, Concatenate, LeakyReLU, ELU, Activation, PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight
import gc

# %% [markdown]
# # **Data Loading**

# %%
from google.colab import drive
drive.mount('/content/drive/')
gc.collect()
# Out:
# Mounted at /content/drive/
# 59

# %%
input_path='/content/drive/MyDrive/data_preprocessed_python/'

# %%
def baseline_remove(XR):
  XT = XR[:, 384:]
  XB_ = (XR[:, :1*128] + XR[:, 1*128:2*128] + XR[:, 2*128:3*128])/3.0
  for i in range(60):
    XT[:, i*128:(i+1)*128] = XT[:, i*128:(i+1)*128] - XB_
  return XT

# %%
new_channels = [0,1,18,2,3,5,4,23,6,7,9,8,15,10,11,12,14,13,
 16,17,18,19,20,22,21,23,24,25,27,26,15,28,29,30,14,31]

# %%
eeg_signal = []
valence = []
arousal = []
window_size = 256
no_channels = 32
no_new_channels = len(new_channels)
no_videos = 40
Trsld = 5

for person in range(6,7):
  print('Person No.' + str(person))
  
  
  # EEG files address
  if person < 10 :
    address = input_path+'s0'+str(person)+'.dat'
  else :
    address = input_path+'s'+str(person)+'.dat'

  with open(address, 'rb') as file:
    data = pkl.load(file, encoding = 'latin1')

  eeg = data['data']
  label = data['labels']
  
  # Assigning classes
  label[label<Trsld] = 0
  label[label>=Trsld] = 1

  val = label.T[0] # Valence label
  aro = label.T[1] # Arousal label

  del data, label
  # Iterating through 40 vidoes/trials
  for i in range(no_videos):
    sig = eeg[i][:no_channels, :]
    sig = baseline_remove(sig)
    temp = []
    for j in new_channels:
      temp.append(sig[j, :])
    sig = np.reshape(temp,[no_new_channels,-1])
    # Segmenting into 2 seconds (256 timesteps) windows without overlap
    start = 0
    while start + window_size <=sig.shape[1]:
      eeg_signal.append(sig[:, start:start+window_size].T)
      valence.append(val[i])
      arousal.append(aro[i])
      start += window_size 
  del eeg, val, aro, sig
eeg_signal = np.reshape(eeg_signal,[-1,window_size,no_new_channels])
data = np.asarray(eeg_signal, dtype = np.float32) # Using 32 bit floating point value to save memory
del eeg_signal
valence = np.asarray(valence, dtype = np.int8)
arousal = np.asarray(arousal, dtype = np.int8)

print(data.shape)
print(valence.shape, valence[valence == 0].shape, valence[valence == 1].shape)
print(arousal.shape, arousal[arousal == 0].shape, arousal[arousal == 1].shape)

valence = np_utils.to_categorical(valence)
arousal = np_utils.to_categorical(arousal)
gc.collect()
# Out:
# Person No.6
# (1200, 256, 36)
# (1200,) (300,) (900,)
# (1200,) (690,) (510,)
# 0

# %%
def simple_2D_CNN(x): 
  x = BatchNormalization()(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=False))(x)
  x = BatchNormalization()(x)
  x = Dropout(0.4)(x)
  x = Dense(32, activation='relu')(x)
  x = Dropout(0.1)(x)
  x = Dense(2, activation='softmax')(x)
  return x

def get_model(): 
  input_shape = (data.shape[1], data.shape[2]) 
  a = Input(input_shape) 
  out = simple_2D_CNN(a) 
  model = Model(a, out) 
  opt = keras.optimizers.Adam(learning_rate=1e-04) 
  model.compile(loss=keras.losses.categorical_crossentropy, metrics=["accuracy"], optimizer=opt) 
  return model 
model = get_model() 
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 36)]         0
#
#  batch_normalization (BatchN  (None, 256, 36)          144
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 256, 64)          17664
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_4 (Bidirectio  (None, 64)               24832
#  nal)
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 119,538
# Trainable params: 119,338
# Non-trainable params: 200
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
batch_size = 64
epochs = 100
kfold = KFold(n_splits=10, random_state=1, shuffle=True)
gc.collect()
# Out:
# 38761

# %%
def call_class_weights(yt):
  y_integers = np.argmax(yt, axis=1)
  class_weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(y_integers), y = y_integers)
  d_class_weights = dict(enumerate(class_weights))
  return d_class_weights

# %% [markdown]
# # **Arousal**

# %%
#arousal
X_train, x_test, Y_train, y_test = train_test_split(data,arousal, test_size=0.1, random_state=4)
print(X_train.shape,x_test.shape,Y_train.shape,y_test.shape)
# Out:
# (1080, 256, 36) (120, 256, 36) (1080, 2) (120, 2)

# %%
val_res = {'accuracy': [], 'f1_score': [], 'confusion_matrix': []}
foldNum=0
#model = get_model()
for train_index, val_index in kfold.split(X_train, Y_train):
  foldNum = foldNum + 1
  model = get_model()
  print("Results for fold",foldNum)
  x_train, x_val = X_train[train_index], X_train[val_index]
  y_train, y_val = Y_train[train_index], Y_train[val_index]
  class_weight = call_class_weights(y_train)
  history = model.fit(x_train, y_train, epochs=epochs, class_weight=class_weight, batch_size=batch_size, verbose=1, validation_data=(x_val, y_val),shuffle=True)
  acc = model.evaluate(x_test, y_test)
  print(acc)
  val_res['accuracy'].append(acc)
  pred = model.predict(x_test)
  f1scr = f1_score(y_test.argmax(1), pred.argmax(1), average='macro')
  print(f1scr)
  pd.DataFrame(history.history).plot(figsize=(8,5))
  plt.show()
  val_res['f1_score'].append(f1scr)
  val_res['confusion_matrix'].append(confusion_matrix(y_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter
  del x_train, x_val, y_train, y_val, acc, f1scr
  gc.collect()
# Out:
# Results for fold 1
# Epoch 1/100
# 16/16 [==============================] - 41s 1s/step - loss: 0.8204 - accuracy: 0.4825 - val_loss: 0.6883 - val_accuracy: 0.5741
# Epoch 2/100
# 16/16 [==============================] - 19s 1s/step - loss: 0
100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1549 - accuracy: 0.9444 - val_loss: 0.6617 - val_accuracy: 0.7407
# Epoch 50/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1466 - accuracy: 0.9527 - val_loss: 0.6507 - val_accuracy: 0.7500
# Epoch 51/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1364 - accuracy: 0.9537 - val_loss: 0.5771 - val_accuracy: 0.7870
# Epoch 52/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1319 - accuracy: 0.9547 - val_loss: 0.6926 - val_accuracy: 0.7407
# Epoch 53/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1280 - accuracy: 0.9537 - val_loss: 0.6565 - val_accuracy: 0.7593
# Epoch 54/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1270 - accuracy: 0.9547 - val_loss: 0.4807 - val_accuracy: 0.8056
# Epoch 55/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1012 - accuracy: 0.9712 - val_loss: 0.6071 - val_accuracy: 0.7685
# Epoch 56/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1064 - accuracy: 0.9650 - val_loss: 0.4517 - val_accuracy: 0.8519
# Epoch 57/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1134 - accuracy: 0.9650 - val_loss: 0.7455 - val_accuracy: 0.7685
# Epoch 58/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0979 - accuracy: 0.9671 - val_loss: 0.6955 - val_accuracy: 0.7685
# Epoch 59/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0901 - accuracy: 0.9753 - val_loss: 0.6995 - val_accuracy: 0.7685
# Epoch 60/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0830 - accuracy: 0.9846 - val_loss: 0.7223 - val_accuracy: 0.7685
# Epoch 61/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0768 - accuracy: 0.9866 - val_loss: 0.7170 - val_accuracy: 0.7778
# Epoch 62/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0714 - accuracy: 0.9815 - val_loss: 0.6436 - val_accuracy: 0.7870
# Epoch 63/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0840 - accuracy: 0.9743 - val_loss: 0.5950 - val_accuracy: 0.7963
# Epoch 64/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0646 - accuracy: 0.9846 - val_loss: 0.6138 - val_accuracy: 0.8148
# Epoch 65/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0638 - accuracy: 0.9877 - val_loss: 0.5960 - val_accuracy: 0.7870
# Epoch 66/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0569 - accuracy: 0.9846 - val_loss: 0.7041 - val_accuracy: 0.7593
# Epoch 67/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0655 - accuracy: 0.9866 - val_loss: 0.5631 - val_accuracy: 0.8241
# Epoch 68/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0747 - accuracy: 0.9815 - val_loss: 1.0367 - val_accuracy: 0.7222
# Epoch 69/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0708 - accuracy: 0.9774 - val_loss: 0.9123 - val_accuracy: 0.7593
# Epoch 70/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0616 - accuracy: 0.9877 - val_loss: 0.8466 - val_accuracy: 0.7685
# Epoch 71/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0537 - accuracy: 0.9825 - val_loss: 0.6201 - val_accuracy: 0.7963
# Epoch 72/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0546 - accuracy: 0.9856 - val_loss: 0.5222 - val_accuracy: 0.8333
# Epoch 73/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0443 - accuracy: 0.9897 - val_loss: 0.5233 - val_accuracy: 0.8426
# Epoch 74/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0403 - accuracy: 0.9938 - val_loss: 0.5285 - val_accuracy: 0.8241
# Epoch 75/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0391 - accuracy: 0.9918 - val_loss: 0.5470 - val_accuracy: 0.8148
# Epoch 76/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0396 - accuracy: 0.9949 - val_loss: 0.5923 - val_accuracy: 0.8056
# Epoch 77/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0596 - accuracy: 0.9835 - val_loss: 0.5234 - val_accuracy: 0.8426
# Epoch 78/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0477 - accuracy: 0.9877 - val_loss: 0.5825 - val_accuracy: 0.8333
# Epoch 79/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0363 - accuracy: 0.9949 - val_loss: 0.7044 - val_accuracy: 0.7963
# Epoch 80/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0484 - accuracy: 0.9856 - val_loss: 0.5737 - val_accuracy: 0.8426
# Epoch 81/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0353 - accuracy: 0.9938 - val_loss: 0.7460 - val_accuracy: 0.7593
# Epoch 82/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0344 - accuracy: 0.9949 - val_loss: 0.6306 - val_accuracy: 0.8056
# Epoch 83/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0279 - accuracy: 0.9959 - val_loss: 0.6655 - val_accuracy: 0.8056
# Epoch 84/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0240 - accuracy: 0.9959 - val_loss: 0.6295 - val_accuracy: 0.8148
# Epoch 85/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0304 - accuracy: 0.9949 - val_loss: 0.6195 - val_accuracy: 0.8148
# Epoch 86/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0278 - accuracy: 0.9938 - val_loss: 0.6254 - val_accuracy: 0.8056
# Epoch 87/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0270 - accuracy: 0.9979 - val_loss: 0.5360 - val_accuracy: 0.8333
# Epoch 88/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0238 - accuracy: 0.9959 - val_loss: 0.5655 - val_accuracy: 0.8426
# Epoch 89/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0242 - accuracy: 0.9979 - val_loss: 0.7339 - val_accuracy: 0.7778
# Epoch 90/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0210 - accuracy: 0.9990 - val_loss: 0.6827 - val_accuracy: 0.8148
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0188 - accuracy: 0.9990 - val_loss: 0.7465 - val_accuracy: 0.8056
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0187 - accuracy: 0.9979 - val_loss: 0.5739 - val_accuracy: 0.8611
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0175 - accuracy: 0.9979 - val_loss: 0.6705 - val_accuracy: 0.8241
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0210 - accuracy: 0.9969 - val_loss: 0.7768 - val_accuracy: 0.7685
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0188 - accuracy: 0.9990 - val_loss: 0.6167 - val_accuracy: 0.8426
# Epoch 96/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0163 - accuracy: 0.9979 - val_loss: 0.6940 - val_accuracy: 0.8241
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0163 - accuracy: 0.9990 - val_loss: 0.6015 - val_accuracy: 0.8426
# Epoch 98/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0194 - accuracy: 0.9969 - val_loss: 0.8271 - val_accuracy: 0.7685
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0199 - accuracy: 0.9979 - val_loss: 0.6540 - val_accuracy: 0.8333
# Epoch 100/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0296 - accuracy: 0.9928 - val_loss: 0.6192 - val_accuracy: 0.8333
# 4/4 [==============================] - 1s 172ms/step - loss: 0.9213 - accuracy: 0.7583
# [0.9212842583656311, 0.7583333253860474]
# 0.7533838849124797
# Results for fold 3
# Epoch 1/100
# 16/16 [==============================] - 40s 1s/step - loss: 0.7641 - accuracy: 0.4938 - val_loss: 0.6933 - val_accuracy: 0.4630
# Epoch 2/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6959 - accuracy: 0.5833 - val_loss: 0.6914 - val_accuracy: 0.5370
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6821 - accuracy: 0.6060 - val_loss: 0.6889 - val_accuracy: 0.5648
# Epoch 4/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6454 - accuracy: 0.6255 - val_loss: 0.6875 - val_accuracy: 0.6019
# Epoch 5/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6514 - accuracy: 0.6193 - val_loss: 0.6855 - val_accuracy: 0.6296
# Epoch 6/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6099 - accuracy: 0.6698 - val_loss: 0.6831 - val_accuracy: 0.6296
# Epoch 7/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5828 - accuracy: 0.7140 - val_loss: 0.6800 - val_accuracy: 0.6759
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.
100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1911 - accuracy: 0.9352 - val_loss: 0.4413 - val_accuracy: 0.7778
# Epoch 40/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1779 - accuracy: 0.9342 - val_loss: 0.4458 - val_accuracy: 0.7963
# Epoch 41/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1798 - accuracy: 0.9393 - val_loss: 0.4722 - val_accuracy: 0.8148
# Epoch 42/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1717 - accuracy: 0.9372 - val_loss: 0.4222 - val_accuracy: 0.7963
# Epoch 43/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1630 - accuracy: 0.9537 - val_loss: 0.5153 - val_accuracy: 0.7778
# Epoch 44/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1478 - accuracy: 0.9537 - val_loss: 0.4476 - val_accuracy: 0.8148
# Epoch 45/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1408 - accuracy: 0.9630 - val_loss: 0.4705 - val_accuracy: 0.8148
# Epoch 46/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1553 - accuracy: 0.9434 - val_loss: 0.4784 - val_accuracy: 0.7778
# Epoch 47/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1340 - accuracy: 0.9630 - val_loss: 0.4732 - val_accuracy: 0.7963
# Epoch 48/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1195 - accuracy: 0.9712 - val_loss: 0.4413 - val_accuracy: 0.8148
# Epoch 49/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1328 - accuracy: 0.9568 - val_loss: 0.4669 - val_accuracy: 0.8056
# Epoch 50/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1118 - accuracy: 0.9681 - val_loss: 0.4913 - val_accuracy: 0.7778
# Epoch 51/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1165 - accuracy: 0.9650 - val_loss: 0.5079 - val_accuracy: 0.7963
# Epoch 52/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1101 - accuracy: 0.9722 - val_loss: 0.5134 - val_accuracy: 0.7778
# Epoch 53/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0923 - accuracy: 0.9743 - val_loss: 0.5915 - val_accuracy: 0.7963
# Epoch 54/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0921 - accuracy: 0.9784 - val_loss: 0.5361 - val_accuracy: 0.7685
# Epoch 55/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1167 - accuracy: 0.9609 - val_loss: 0.5789 - val_accuracy: 0.7685
# Epoch 56/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0934 - accuracy: 0.9743 - val_loss: 0.5430 - val_accuracy: 0.7963
# Epoch 57/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0910 - accuracy: 0.9712 - val_loss: 0.5240 - val_accuracy: 0.8241
# Epoch 58/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0881 - accuracy: 0.9763 - val_loss: 0.5341 - val_accuracy: 0.7685
# Epoch 59/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0760 - accuracy: 0.9794 - val_loss: 0.5834 - val_accuracy: 0.7963
# Epoch 60/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0806 - accuracy: 0.9774 - val_loss: 0.6593 - val_accuracy: 0.7778
# Epoch 61/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0779 - accuracy: 0.9763 - val_loss: 0.5965 - val_accuracy: 0.8056
# Epoch 62/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0681 - accuracy: 0.9877 - val_loss: 0.5757 - val_accuracy: 0.8148
# Epoch 63/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0812 - accuracy: 0.9763 - val_loss: 0.5857 - val_accuracy: 0.7963
# Epoch 64/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0593 - accuracy: 0.9897 - val_loss: 0.5612 - val_accuracy: 0.8241
# Epoch 65/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0651 - accuracy: 0.9835 - val_loss: 0.5684 - val_accuracy: 0.8148
# Epoch 66/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0477 - accuracy: 0.9877 - val_loss: 0.5635 - val_accuracy: 0.8056
# Epoch 67/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0676 - accuracy: 0.9784 - val_loss: 0.6007 - val_accuracy: 0.7963
# Epoch 68/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0550 - accuracy: 0.9877 - val_loss: 0.5977 - val_accuracy: 0.8241
# Epoch 69/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0670 - accuracy: 0.9784 - val_loss: 0.5816 - val_accuracy: 0.8056
# Epoch 70/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0602 - accuracy: 0.9835 - val_loss: 0.6832 - val_accuracy: 0.7593
# Epoch 71/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0518 - accuracy: 0.9825 - val_loss: 0.6449 - val_accuracy: 0.7963
# Epoch 72/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0433 - accuracy: 0.9907 - val_loss: 0.6985 - val_accuracy: 0.7870
# Epoch 73/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0404 - accuracy: 0.9918 - val_loss: 0.6365 - val_accuracy: 0.8148
# Epoch 74/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0396 - accuracy: 0.9918 - val_loss: 0.6568 - val_accuracy: 0.8148
# Epoch 75/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0323 - accuracy: 0.9949 - val_loss: 0.6315 - val_accuracy: 0.8241
# Epoch 76/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0362 - accuracy: 0.9928 - val_loss: 0.6898 - val_accuracy: 0.8056
# Epoch 77/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0331 - accuracy: 0.9938 - val_loss: 0.6153 - val_accuracy: 0.7963
# Epoch 78/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0372 - accuracy: 0.9928 - val_loss: 0.6808 - val_accuracy: 0.7593
# Epoch 79/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0298 - accuracy: 0.9949 - val_loss: 0.6235 - val_accuracy: 0.8056
# Epoch 80/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0277 - accuracy: 0.9979 - val_loss: 0.6703 - val_accuracy: 0.7870
# Epoch 81/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0326 - accuracy: 0.9938 - val_loss: 0.7375 - val_accuracy: 0.7870
# Epoch 82/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0330 - accuracy: 0.9928 - val_loss: 0.7358 - val_accuracy: 0.7870
# Epoch 83/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0359 - accuracy: 0.9938 - val_loss: 0.6965 - val_accuracy: 0.7778
# Epoch 84/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0255 - accuracy: 0.9969 - val_loss: 0.7915 - val_accuracy: 0.7870
# Epoch 85/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0281 - accuracy: 0.9938 - val_loss: 0.7565 - val_accuracy: 0.8056
# Epoch 86/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0248 - accuracy: 0.9949 - val_loss: 0.6922 - val_accuracy: 0.8241
# Epoch 87/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0275 - accuracy: 0.9938 - val_loss: 0.6171 - val_accuracy: 0.7963
# Epoch 88/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0230 - accuracy: 0.9969 - val_loss: 0.7862 - val_accuracy: 0.7778
# Epoch 89/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0261 - accuracy: 0.9969 - val_loss: 0.7137 - val_accuracy: 0.8056
# Epoch 90/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0322 - accuracy: 0.9907 - val_loss: 0.6941 - val_accuracy: 0.7963
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0288 - accuracy: 0.9928 - val_loss: 0.6957 - val_accuracy: 0.8056
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.7209 - val_accuracy: 0.7778
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.7855 - val_accuracy: 0.7963
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.7084 - val_accuracy: 0.8056
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.8056
# Epoch 96/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0169 - accuracy: 0.9979 - val_loss: 0.7485 - val_accuracy: 0.8056
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0151 - accuracy: 0.9990 - val_loss: 0.7245 - val_accuracy: 0.8148
# Epoch 98/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0146 - accuracy: 0.9990 - val_loss: 0.7120 - val_accuracy: 0.8056
# Epoch 99/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0185 - accuracy: 0.9959 - val_loss: 0.7052 - val_accuracy: 0.8148
# Epoch 100/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.7310 - val_accuracy: 0.7963
# 4/4 [==============================] - 1s 181ms/step - loss: 1.0754 - accuracy: 0.8000
# [1.0753916501998901, 0.800000011920929]
# 0.7942857142857143
# Results for fold 4
# Epoch 1/100
# 16/16 [==============================] - 40s 1s/step - loss: 0.7962 - accuracy: 0.4949 - val_loss: 0.6916 - val_accuracy: 0.5000
# Epoch 2/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.7102 - accuracy: 0.5751 - val_loss: 0.6885 - val_accuracy: 0.5648
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6963 - accuracy: 0.5772 - val_loss: 0.6860 - val_accuracy: 0.5833
# Epoch 4/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6441 - accuracy: 0.6348 - val_loss: 0.6832 - val_accuracy: 0.6389
# Epoch 5/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.6787 - accuracy: 0.6132 - val_loss: 0.6801 - val_accuracy: 0.6667
# Epoch 6/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.6352 - accuracy: 0.6481 - val_loss: 0.6766 - val_accuracy: 0.6944
# Epoch 7/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.6077 - accuracy: 0.6842 - val_loss: 0.6737 - val_accuracy: 0.7315
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5895 - accuracy: 0.6790 - val_loss: 0.6702 - val_accuracy: 0.7685
# Epoch 9/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5573 - accuracy: 0.7315 - val_loss: 0.6658 - val_accuracy: 0.7130
# Epoch 10/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5359 - accuracy: 0.7428 - val_loss: 0.6606 - val_accuracy: 0.7315
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5269 - accuracy: 0.7438 - val_loss: 0.6553 - val_accuracy: 0.7407
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5159 - accuracy: 0.7407 - val_loss: 0.6514 - val_accuracy: 0.7130
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4967 - accuracy: 0.7623 - val_loss: 0.6456 - val_accuracy: 0.7315
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4792 - accuracy: 0.7726 - val_loss: 0.6409 - val_accuracy: 0.7500
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4836 - accuracy: 0.7623 - val_loss: 0.6348 - val_accuracy: 0.7407
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4462 - accuracy: 0.7932 - val_loss: 0.6267 - val_accuracy: 0.7500
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4446 - accuracy: 0.7912 - val_loss: 0.6181 - val_accuracy: 0.7685
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4343 - accuracy: 0.7994 - val_loss: 0.6081 - val_accuracy: 0.7778
# Epoch 19/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4299 - accuracy: 0.8014 - val_loss: 0.5970 - val_accuracy: 0.7685
# Epoch 20/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4058 - accuracy: 0.8076 - val_loss: 0.5806 - val_accuracy: 0.7685
# Epoch 21/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3798 - accuracy: 0.8385 - val_loss: 0.5695 - val_accuracy: 0.7778
# Epoch 22/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3651 - accuracy: 0.8426 - val_loss: 0.5580 - val_accuracy: 0.7870
# Epoch 23/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3666 - accuracy: 0.8395 - val_loss: 0.5427 - val_accuracy: 0.7870
# Epoch 24/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3488 - accuracy: 0.8447 - val_loss: 0.5284 - val_accuracy: 0.7778
# Epoch 25/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3385 - accuracy: 0.8508 - val_loss: 0.5122 - val_accuracy: 0.7685
# Epoch 26/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3186 - accuracy: 0.8580 - val_loss: 0.4984 - val_accuracy: 0.7685
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3207 - accuracy: 0.8621 - val_loss: 0.4841 - val_accuracy: 0.7778
# Epoch 28/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3105 - accuracy: 0.8611 - val_loss: 0.4658 - val_accuracy: 0.8148
# Epoch 29/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2906 - accuracy: 0.8827 - val_loss: 0.4538 - val_accuracy: 0.7963
# Epoch 30/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2800 - accuracy: 0.8786 - val_loss: 0.4463 - val_accuracy: 0.7870
# Epoch 31/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2731 - accuracy: 0.8848 - val_loss: 0.4219 - val_accuracy: 0.8333
# Epoch 32/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2652 - accuracy: 0.8899 - val_loss: 0.4141 - val_accuracy: 0.8056
# Epoch 33/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2476 - accuracy: 0.9053 - val_loss: 0.4052 - val_accuracy: 0.7870
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2382 - accuracy: 0.8992 - val_loss: 0.3816 - val_accuracy: 0.7963
# Epoch 35/100
# ...
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0221 - accuracy: 0.9990 - val_loss: 0.8918 - val_accuracy: 0.8333
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0243 - accuracy: 0.9969 - val_loss: 0.7412 - val_accuracy: 0.8241
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.7801 - val_accuracy: 0.8333
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0159 - accuracy: 0.9990 - val_loss: 0.8361 - val_accuracy: 0.8241
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0177 - accuracy: 0.9990 - val_loss: 0.7510 - val_accuracy: 0.8241
# Epoch 96/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0167 - accuracy: 0.9990 - val_loss: 0.7683 - val_accuracy: 0.8241
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0361 - accuracy: 0.9887 - val_loss: 0.6956 - val_accuracy: 0.8148
# Epoch 98/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0363 - accuracy: 0.9907 - val_loss: 0.7776 - val_accuracy: 0.8241
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.7621 - val_accuracy: 0.8333
# Epoch 100/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0255 - accuracy: 0.9959 - val_loss: 0.7939 - val_accuracy: 0.8241
# 4/4 [==============================] - 1s 188ms/step - loss: 0.6748 - accuracy: 0.8417
# [0.6748422980308533, 0.8416666388511658]
# 0.8397863818424565
# Results for fold 10
# Epoch 1/100
# 16/16 [==============================] - 41s 1s/step - loss: 0.8076 - accuracy: 0.5288 - val_loss: 0.6871 - val_accuracy: 0.6389
# Epoch 2/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.7080 - accuracy: 0.5700 - val_loss: 0.6858 - val_accuracy: 0.6111
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6750 - accuracy: 0.6070 - val_loss: 0.6843 - val_accuracy: 0.6111
# Epoch 4/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6707 - accuracy: 0.6204 - val_loss: 0.6820 - val_accuracy: 0.6204
# Epoch 5/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6257 - accuracy: 0.6584 - val_loss: 0.6797 - val_accuracy: 0.6574
# Epoch 6/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6149 - accuracy: 0.6708 - val_loss: 0.6770 - val_accuracy: 0.6852
# Epoch 7/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5808 - accuracy: 0.6996 - val_loss: 0.6736 - val_accuracy: 0.7222
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5816 - accuracy: 0.6924 - val_loss: 0.6707 - val_accuracy: 0.7222
# Epoch 9/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5379 - accuracy: 0.7335 - val_loss: 0.6662 - val_accuracy: 0.7130
# Epoch 10/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5434 - accuracy: 0.7253 - val_loss: 0.6609 - val_accuracy: 0.7222
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5148 - accuracy: 0.7510 - val_loss: 0.6556 - val_accuracy: 0.7593
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4843 - accuracy: 0.7603 - val_loss: 0.6502 - val_accuracy: 0.7500
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4868 - accuracy: 0.7541 - val_loss: 0.6438 - val_accuracy: 0.7593
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4721 - accuracy: 0.7798 - val_loss: 0.6359 - val_accuracy: 0.7685
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4643 - accuracy: 0.7840 - val_loss: 0.6270 - val_accuracy: 0.7778
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4297 - accuracy: 0.7942 - val_loss: 0.6188 - val_accuracy: 0.7778
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4342 - accuracy: 0.7984 - val_loss: 0.6084 - val_accuracy: 0.7685
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4188 - accuracy: 0.8066 - val_loss: 0.5976 - val_accuracy: 0.7778
# Epoch 19/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4006 - accuracy: 0.8107 - val_loss: 0.5837 - val_accuracy: 0.8333
# Epoch 20/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4033 - accuracy: 0.8261 - val_loss: 0.5715 - val_accuracy: 0.8241
# Epoch 21/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3643 - accuracy: 0.8395 - val_loss: 0.5614 - val_accuracy: 0.8148
# Epoch 22/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3844 - accuracy: 0.8282 - val_loss: 0.5462 - val_accuracy: 0.8056
# Epoch 23/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3509 - accuracy: 0.8519 - val_loss: 0.5332 - val_accuracy: 0.8056
# Epoch 24/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3585 - accuracy: 0.8477 - val_loss: 0.5193 - val_accuracy: 0.7963
# Epoch 25/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3405 - accuracy: 0.8683 - val_loss: 0.5016 - val_accuracy: 0.7963
# Epoch 26/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3275 - accuracy: 0.8519 - val_loss: 0.4854 - val_accuracy: 0.8148
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3107 - accuracy: 0.8693 - val_loss: 0.4764 - val_accuracy: 0.8148
# Epoch 28/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2950 - accuracy: 0.8848 - val_loss: 0.4575 - val_accuracy: 0.8426
# Epoch 29/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3093 - accuracy: 0.8621 - val_loss: 0.4410 - val_accuracy: 0.8519
# Epoch 30/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2634 - accuracy: 0.9002 - val_loss: 0.4239 - val_accuracy: 0.8241
# Epoch 31/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2548 - accuracy: 0.9033 - val_loss: 0.4051 - val_accuracy: 0.8148
# Epoch 32/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2566 - accuracy: 0.8930 - val_loss: 0.3884 - val_accuracy: 0.8333
# Epoch 33/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2495 - accuracy: 0.9033 - val_loss: 0.3766 - val_accuracy: 0.8148
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2259 - accuracy: 0.9156 - val_loss: 0.3858 - val_accuracy: 0.8148
# Epoch 35/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2161 - accuracy: 0.9198 - val_loss: 0.3936 - val_accuracy: 0.7963
# Epoch 36/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2353 - accuracy: 0.9043 - val_loss: 0.3613 - val_accuracy: 0.8333
# Epoch 37/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2137 - accuracy: 0.9280 - val_loss: 0.3599 - val_accuracy: 0.8333
# Epoch 38/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1743 - accuracy: 0.9414 - val_loss: 0.3371 - val_accuracy: 0.8611
# Epoch 39/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1894 - accuracy: 0.9424 - val_loss: 0.3238 - val_accuracy: 0.8519
# Epoch 40/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1820 - accuracy: 0.9403 - val_loss: 0.3411 - val_accuracy: 0.8333
# Epoch 41/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1701 - accuracy: 0.9434 - val_loss: 0.3561 - val_accuracy: 0.8333
# Epoch 42/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1702 - accuracy: 0.9414 - val_loss: 0.3885 - val_accuracy: 0.8241
# Epoch 43/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1687 - accuracy: 0.9424 - val_loss: 0.3863 - val_accuracy: 0.8241
# Epoch 44/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1629 - accuracy: 0.9455 - val_loss: 0.3547 - val_accuracy: 0.8333
# Epoch 45/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1495 - accuracy: 0.9486 - val_loss: 0.3937 - val_accuracy: 0.8333
# Epoch 46/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1414 - accuracy: 0.9547 - val_loss: 0.4031 - val_accuracy: 0.8241
# Epoch 47/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1310 - accuracy: 0.9558 - val_loss: 0.3936 - val_accuracy: 0.8333
# Epoch 48/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1211 - accuracy: 0.9681 - val_loss: 0.4038 - val_accuracy: 0.8333
# Epoch 49/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1189 - accuracy: 0.9671 - val_loss: 0.4733 - val_accuracy: 0.8241
# Epoch 50/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1245 - accuracy: 0.9599 - val_loss: 0.4018 - val_accuracy: 0.8333
# Epoch 51/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1109 - accuracy: 0.9702 - val_loss: 0.3480 - val_accuracy: 0.8796
# Epoch 52/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1001 - accuracy: 0.9743 - val_loss: 0.3460 - val_accuracy: 0.8611
# Epoch 53/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0999 - accuracy: 0.9691 - val_loss: 0.3509 - val_accuracy: 0.8426
# Epoch 54/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1181 - accuracy: 0.9588 - val_loss: 0.3907 - val_accuracy: 0.8333
# Epoch 55/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0959 - accuracy: 0.9691 - val_loss: 0.3647 - val_accuracy: 0.8611
# Epoch 56/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0915 - accuracy: 0.9743 - val_loss: 0.3871 - val_accuracy: 0.8519
# Epoch 57/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0779 - accuracy: 0.9774 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 58/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0754 - accuracy: 0.9846 - val_loss: 0.4196 - val_accuracy: 0.8333
# Epoch 59/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0757 - accuracy: 0.9774 - val_loss: 0.4260 - val_accuracy: 0.8426
# Epoch 60/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0703 - accuracy: 0.9825 - val_loss: 0.4183 - val_accuracy: 0.8333
# Epoch 61/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0834 - accuracy: 0.9671 - val_loss: 0.3887 - val_accuracy: 0.8426
# Epoch 62/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0630 - accuracy: 0.9825 - val_loss: 0.4356 - val_accuracy: 0.8426
# Epoch 63/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0559 - accuracy: 0.9866 - val_loss: 0.4390 - val_accuracy: 0.8519
# Epoch 64/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0505 - accuracy: 0.9897 - val_loss: 0.4277 - val_accuracy: 0.8704
# Epoch 65/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0513 - accuracy: 0.9897 - val_loss: 0.4916 - val_accuracy: 0.8333
# Epoch 66/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0538 - accuracy: 0.9877 - val_loss: 0.4833 - val_accuracy: 0.8519
# Epoch 67/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0483 - accuracy: 0.9907 - val_loss: 0.4553 - val_accuracy: 0.8333
# Epoch 68/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0500 - accuracy: 0.9846 - val_loss: 0.4357 - val_accuracy: 0.8611
# Epoch 69/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0506 - accuracy: 0.9856 - val_loss: 0.4351 - val_accuracy: 0.8611
# Epoch 70/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0393 - accuracy: 0.9949 - val_loss: 0.4634 - val_accuracy: 0.8241
# Epoch 71/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0400 - accuracy: 0.9887 - val_loss: 0.4570 - val_accuracy: 0.8426
# Epoch 72/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0433 - accuracy: 0.9897 - val_loss: 0.4774 - val_accuracy: 0.8611
# Epoch 73/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0474 - accuracy: 0.9866 - val_loss: 0.4752 - val_accuracy: 0.8519
# Epoch 74/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0337 - accuracy: 0.9959 - val_loss: 0.4767 - val_accuracy: 0.8611
# Epoch 75/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0354 - accuracy: 0.9949 - val_loss: 0.4791 - val_accuracy: 0.8426
# Epoch 76/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0328 - accuracy: 0.9938 - val_loss: 0.4385 - val_accuracy: 0.8611
# Epoch 77/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0285 - accuracy: 0.9969 - val_loss: 0.4099 - val_accuracy: 0.8796
# Epoch 78/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0386 - accuracy: 0.9918 - val_loss: 0.4993 - val_accuracy: 0.8796
# Epoch 79/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0413 - accuracy: 0.9887 - val_loss: 0.5105 - val_accuracy: 0.8796
# Epoch 80/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0306 - accuracy: 0.9928 - val_loss: 0.4823 - val_accuracy: 0.8796
# Epoch 81/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0332 - accuracy: 0.9949 - val_loss: 0.5849 - val_accuracy: 0.8519
# Epoch 82/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0275 - accuracy: 0.9949 - val_loss: 0.5203 - val_accuracy: 0.8611
# Epoch 83/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0369 - accuracy: 0.9918 - val_loss: 0.4951 - val_accuracy: 0.8426
# Epoch 84/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0336 - accuracy: 0.9928 - val_loss: 0.5193 - val_accuracy: 0.8611
# Epoch 85/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0274 - accuracy: 0.9928 - val_loss: 0.5052 - val_accuracy: 0.8704
# Epoch 86/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0268 - accuracy: 0.9959 - val_loss: 0.4781 - val_accuracy: 0.9074
# Epoch 87/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0206 - accuracy: 0.9990 - val_loss: 0.5512 - val_accuracy: 0.8611
# Epoch 88/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0251 - accuracy: 0.9959 - val_loss: 0.5577 - val_accuracy: 0.8519
# Epoch 89/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.8519
# Epoch 90/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0233 - accuracy: 0.9969 - val_loss: 0.5230 - val_accuracy: 0.8796
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0188 - accuracy: 0.9979 - val_loss: 0.4817 - val_accuracy: 0.8704
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0189 - accuracy: 0.9959 - val_loss: 0.4895 - val_accuracy: 0.8704
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0187 - accuracy: 0.9979 - val_loss: 0.4911 - val_accuracy: 0.8611
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0231 - accuracy: 0.9979 - val_loss: 0.4993 - val_accuracy: 0.8796
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.5121 - val_accuracy: 0.8704
# Epoch 96/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0161 - accuracy: 0.9990 - val_loss: 0.4791 - val_accuracy: 0.8796
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0201 - accuracy: 0.9969 - val_loss: 0.5218 - val_accuracy: 0.8796
# Epoch 98/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.8704
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0132 - accuracy: 0.9990 - val_loss: 0.5343 - val_accuracy: 0.8704
# Epoch 100/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.5627 - val_accuracy: 0.8704
# 4/4 [==============================] - 1s 171ms/step - loss: 0.7563 - accuracy: 0.8167
# [0.7563130855560303, 0.8166666626930237]
# 0.8148148148148148

# %%
acrc = np.array(val_res['accuracy']).mean(axis=0)
f1scr = np.array(val_res['f1_score']).mean(axis=0)
print("Accuracy  : {}".format(acrc[1]))
print("F1_Score  : {}".format(f1scr))
cmatrix = np.array(val_res['confusion_matrix']).mean(axis=0)
c_matrix = cmatrix/np.sum(cmatrix, axis=1).reshape(2,1)
import seaborn as sns
figure = plt.figure(figsize=(9, 9))
sns.heatmap(c_matrix, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Accuracy  : 0.8191666722297668
# F1_Score  : 0.8146222941448832
