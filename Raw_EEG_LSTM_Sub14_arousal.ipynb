# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import pickle as pkl
from tensorflow import keras
import tensorflow.keras.backend as K
from keras.models import Sequential,Model
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Flatten, Input, Reshape, BatchNormalization, Bidirectional, LSTM, Multiply, Activation, Normalization, TimeDistributed
from keras.layers import Conv3D, Conv2D, Conv1D, MaxPool3D, MaxPool2D, MaxPool1D, AvgPool3D, AvgPool2D, AvgPool1D, GlobalMaxPool3D, Attention, Subtract
from keras.layers import GlobalMaxPool2D, GlobalMaxPool1D, SpatialDropout3D, SpatialDropout2D, SpatialDropout1D, GlobalAvgPool3D, MultiHeadAttention
from keras.layers import GlobalAvgPool2D, GlobalAvgPool1D, SeparableConv2D, SeparableConv1D, Add, Concatenate, LeakyReLU, ELU, Activation, PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight
import gc

# %% [markdown]
# # **Data Loading**

# %%
from google.colab import drive
drive.mount('/content/drive/')
gc.collect()
# Out:
# Mounted at /content/drive/
# 59

# %%
input_path='/content/drive/MyDrive/data_preprocessed_python/'

# %%
def baseline_remove(XR):
  XT = XR[:, 384:]
  XB_ = (XR[:, :1*128] + XR[:, 1*128:2*128] + XR[:, 2*128:3*128])/3.0
  for i in range(60):
    XT[:, i*128:(i+1)*128] = XT[:, i*128:(i+1)*128] - XB_
  return XT

# %%
new_channels = [0,1,18,2,3,5,4,23,6,7,9,8,15,10,11,12,14,13,
 16,17,18,19,20,22,21,23,24,25,27,26,15,28,29,30,14,31]

# %%
eeg_signal = []
valence = []
arousal = []
window_size = 256
no_channels = 32
no_new_channels = len(new_channels)
no_videos = 40
Trsld = 5

for person in range(14,15):
  print('Person No.' + str(person))
  
  
  # EEG files address
  if person < 10 :
    address = input_path+'s0'+str(person)+'.dat'
  else :
    address = input_path+'s'+str(person)+'.dat'

  with open(address, 'rb') as file:
    data = pkl.load(file, encoding = 'latin1')

  eeg = data['data']
  label = data['labels']
  
  # Assigning classes
  label[label<Trsld] = 0
  label[label>=Trsld] = 1

  val = label.T[0] # Valence label
  aro = label.T[1] # Arousal label

  del data, label
  # Iterating through 40 vidoes/trials
  for i in range(no_videos):
    sig = eeg[i][:no_channels, :]
    sig = baseline_remove(sig)
    temp = []
    for j in new_channels:
      temp.append(sig[j, :])
    sig = np.reshape(temp,[no_new_channels,-1])
    # Segmenting into 2 seconds (256 timesteps) windows without overlap
    start = 0
    while start + window_size <=sig.shape[1]:
      eeg_signal.append(sig[:, start:start+window_size].T)
      valence.append(val[i])
      arousal.append(aro[i])
      start += window_size 
  del eeg, val, aro, sig
eeg_signal = np.reshape(eeg_signal,[-1,window_size,no_new_channels])
data = np.asarray(eeg_signal, dtype = np.float32) # Using 32 bit floating point value to save memory
del eeg_signal
valence = np.asarray(valence, dtype = np.int8)
arousal = np.asarray(arousal, dtype = np.int8)

print(data.shape)
print(valence.shape, valence[valence == 0].shape, valence[valence == 1].shape)
print(arousal.shape, arousal[arousal == 0].shape, arousal[arousal == 1].shape)

valence = np_utils.to_categorical(valence)
arousal = np_utils.to_categorical(arousal)
gc.collect()
# Out:
# Person No.14
# (1200, 256, 36)
# (1200,) (600,) (600,)
# (1200,) (390,) (810,)
# 0

# %%
def simple_2D_CNN(x): 
  x = BatchNormalization()(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=False))(x)
  x = BatchNormalization()(x)
  x = Dropout(0.4)(x)
  x = Dense(32, activation='relu')(x)
  x = Dropout(0.1)(x)
  x = Dense(2, activation='softmax')(x)
  return x

def get_model(): 
  input_shape = (data.shape[1], data.shape[2]) 
  a = Input(input_shape) 
  out = simple_2D_CNN(a) 
  model = Model(a, out) 
  opt = keras.optimizers.Adam(learning_rate=1e-04) 
  model.compile(loss=keras.losses.categorical_crossentropy, metrics=["accuracy"], optimizer=opt) 
  return model 
model = get_model() 
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 36)]         0
#
#  batch_normalization (BatchN  (None, 256, 36)          144
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 256, 64)          17664
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_4 (Bidirectio  (None, 64)               24832
#  nal)
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 119,538
# Trainable params: 119,338
# Non-trainable params: 200
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
batch_size = 64
epochs = 100
kfold = KFold(n_splits=10, random_state=1, shuffle=True)
gc.collect()
# Out:
# 38070

# %%
def call_class_weights(yt):
  y_integers = np.argmax(yt, axis=1)
  class_weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(y_integers), y = y_integers)
  d_class_weights = dict(enumerate(class_weights))
  return d_class_weights

# %% [markdown]
# # **Arousal**

# %%
#arousal
X_train, x_test, Y_train, y_test = train_test_split(data,arousal, test_size=0.1, random_state=4)
print(X_train.shape,x_test.shape,Y_train.shape,y_test.shape)
# Out:
# (1080, 256, 36) (120, 256, 36) (1080, 2) (120, 2)

# %%
val_res = {'accuracy': [], 'f1_score': [], 'confusion_matrix': []}
foldNum=0
#model = get_model()
for train_index, val_index in kfold.split(X_train, Y_train):
  foldNum = foldNum + 1
  model = get_model()
  print("Results for fold",foldNum)
  x_train, x_val = X_train[train_index], X_train[val_index]
  y_train, y_val = Y_train[train_index], Y_train[val_index]
  class_weight = call_class_weights(y_train)
  history = model.fit(x_train, y_train, epochs=epochs, class_weight=class_weight, batch_size=batch_size, verbose=1, validation_data=(x_val, y_val),shuffle=True)
  acc = model.evaluate(x_test, y_test)
  print(acc)
  val_res['accuracy'].append(acc)
  pred = model.predict(x_test)
  f1scr = f1_score(y_test.argmax(1), pred.argmax(1), average='macro')
  print(f1scr)
  pd.DataFrame(history.history).plot(figsize=(8,5))
  plt.show()
  val_res['f1_score'].append(f1scr)
  val_res['confusion_matrix'].append(confusion_matrix(y_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter
  del x_train, x_val, y_train, y_val, acc, f1scr
  gc.collect()
# Out:
# Results for fold 1
# Epoch 1/100
# 16/16 [==============================] - 43s 2s/step - loss: 0.8024 - accuracy: 0.6255 - val_loss: 0.6902 - val_accuracy: 0.5463
# Epoch 2/100
# 16/16 [==============================] - 18s 1s/step - loss: 0
100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5604 - accuracy: 0.7346 - val_loss: 0.6845 - val_accuracy: 0.5370
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5576 - accuracy: 0.7253 - val_loss: 0.6822 - val_accuracy: 0.5463
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5422 - accuracy: 0.7418 - val_loss: 0.6803 - val_accuracy: 0.5463
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5289 - accuracy: 0.7521 - val_loss: 0.6784 - val_accuracy: 0.5463
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5302 - accuracy: 0.7562 - val_loss: 0.6798 - val_accuracy: 0.5185
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4947 - accuracy: 0.7521 - val_loss: 0.6751 - val_accuracy: 0.5185
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5057 - accuracy: 0.7521 - val_loss: 0.6684 - val_accuracy: 0.5833
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4791 - accuracy: 0.7726 - val_loss: 0.6602 - val_accuracy: 0.6111
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4771 - accuracy: 0.7726 - val_loss: 0.6495 - val_accuracy: 0.6111
# Epoch 19/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4475 - accuracy: 0.7932 - val_loss: 0.6428 - val_accuracy: 0.6296
# Epoch 20/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4415 - accuracy: 0.7994 - val_loss: 0.6351 - val_accuracy: 0.6574
# Epoch 21/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4578 - accuracy: 0.7819 - val_loss: 0.6250 - val_accuracy: 0.6852
# Epoch 22/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4189 - accuracy: 0.8138 - val_loss: 0.6193 - val_accuracy: 0.6852
# Epoch 23/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4094 - accuracy: 0.8086 - val_loss: 0.6059 - val_accuracy: 0.6944
# Epoch 24/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4057 - accuracy: 0.8128 - val_loss: 0.5941 - val_accuracy: 0.6944
# Epoch 25/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3771 - accuracy: 0.8302 - val_loss: 0.5888 - val_accuracy: 0.6944
# Epoch 26/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3753 - accuracy: 0.8333 - val_loss: 0.5683 - val_accuracy: 0.7222
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3645 - accuracy: 0.8261 - val_loss: 0.5712 - val_accuracy: 0.7130
# Epoch 28/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3675 - accuracy: 0.8272 - val_loss: 0.5547 - val_accuracy: 0.6852
# Epoch 29/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3598 - accuracy: 0.8488 - val_loss: 0.5346 - val_accuracy: 0.7130
# Epoch 30/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3263 - accuracy: 0.8560 - val_loss: 0.5084 - val_accuracy: 0.7778
# Epoch 31/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3410 - accuracy: 0.8385 - val_loss: 0.5054 - val_accuracy: 0.7407
# Epoch 32/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3239 - accuracy: 0.8621 - val_loss: 0.5108 - val_accuracy: 0.7222
# Epoch 33/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3101 - accuracy: 0.8683 - val_loss: 0.5056 - val_accuracy: 0.7222
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3000 - accuracy: 0.8735 - val_loss: 0.4851 - val_accuracy: 0.7130
# Epoch 35/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2781 - accuracy: 0.8807 - val_loss: 0.4918 - val_accuracy: 0.7222
# Epoch 36/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2904 - accuracy: 0.8745 - val_loss: 0.5065 - val_accuracy: 0.7222
# Epoch 37/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2745 - accuracy: 0.8827 - val_loss: 0.4927 - val_accuracy: 0.7315
# Epoch 38/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2806 - accuracy: 0.8868 - val_loss: 0.4861 - val_accuracy: 0.7500
# Epoch 39/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2390 - accuracy: 0.9115 - val_loss: 0.4728 - val_accuracy: 0.7685
# Epoch 40/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2406 - accuracy: 0.9002 - val_loss: 0.4547 - val_accuracy: 0.7870
# Epoch 41/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2645 - accuracy: 0.8981 - val_loss: 0.4782 - val_accuracy: 0.7593
# Epoch 42/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2229 - accuracy: 0.9228 - val_loss: 0.4938 - val_accuracy: 0.7222
# Epoch 43/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2253 - accuracy: 0.9105 - val_loss: 0.4708 - val_accuracy: 0.7870
# Epoch 44/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2256 - accuracy: 0.9156 - val_loss: 0.5559 - val_accuracy: 0.7222
# Epoch 45/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2004 - accuracy: 0.9187 - val_loss: 0.5642 - val_accuracy: 0.7315
# Epoch 46/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2075 - accuracy: 0.9177 - val_loss: 0.6019 - val_accuracy: 0.7037
# Epoch 47/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1950 - accuracy: 0.9311 - val_loss: 0.5513 - val_accuracy: 0.7778
# Epoch 48/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1656 - accuracy: 0.9331 - val_loss: 0.6121 - val_accuracy: 0.7685
# Epoch 49/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1647 - accuracy: 0.9403 - val_loss: 0.6673 - val_accuracy: 0.7222
# Epoch 50/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1796 - accuracy: 0.9321 - val_loss: 0.6572 - val_accuracy: 0.7315
# Epoch 51/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1668 - accuracy: 0.9362 - val_loss: 0.7218 - val_accuracy: 0.7315
# Epoch 52/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1604 - accuracy: 0.9342 - val_loss: 0.6060 - val_accuracy: 0.7500
# Epoch 53/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1345 - accuracy: 0.9640 - val_loss: 0.7425 - val_accuracy: 0.7130
# Epoch 54/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1331 - accuracy: 0.9537 - val_loss: 0.7054 - val_accuracy: 0.7685
# Epoch 55/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1361 - accuracy: 0.9568 - val_loss: 0.6843 - val_accuracy: 0.7500
# Epoch 56/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1202 - accuracy: 0.9630 - val_loss: 0.6458 - val_accuracy: 0.7685
# Epoch 57/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1142 - accuracy: 0.9650 - val_loss: 0.5745 - val_accuracy: 0.7870
# Epoch 58/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1290 - accuracy: 0.9527 - val_loss: 0.6432 - val_accuracy: 0.7593
# Epoch 59/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1207 - accuracy: 0.9547 - val_loss: 0.7417 - val_accuracy: 0.7407
# Epoch 60/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1069 - accuracy: 0.9681 - val_loss: 0.5232 - val_accuracy: 0.7963
# Epoch 61/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0990 - accuracy: 0.9722 - val_loss: 0.5506 - val_accuracy: 0.7963
# Epoch 62/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1041 - accuracy: 0.9650 - val_loss: 0.4848 - val_accuracy: 0.8056
# Epoch 63/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.1018 - accuracy: 0.9640 - val_loss: 0.5615 - val_accuracy: 0.7963
# Epoch 64/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0835 - accuracy: 0.9794 - val_loss: 0.5655 - val_accuracy: 0.8148
# Epoch 65/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0865 - accuracy: 0.9763 - val_loss: 0.5841 - val_accuracy: 0.7963
# Epoch 66/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0791 - accuracy: 0.9794 - val_loss: 0.5903 - val_accuracy: 0.7778
# Epoch 67/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0771 - accuracy: 0.9805 - val_loss: 0.5644 - val_accuracy: 0.8056
# Epoch 68/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0837 - accuracy: 0.9794 - val_loss: 0.5474 - val_accuracy: 0.8148
# Epoch 69/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0717 - accuracy: 0.9835 - val_loss: 0.7698 - val_accuracy: 0.7593
# Epoch 70/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0657 - accuracy: 0.9835 - val_loss: 0.8817 - val_accuracy: 0.7315
# Epoch 71/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0619 - accuracy: 0.9835 - val_loss: 0.8261 - val_accuracy: 0.7222
# Epoch 72/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0723 - accuracy: 0.9763 - val_loss: 0.4934 - val_accuracy: 0.8333
# Epoch 73/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0646 - accuracy: 0.9815 - val_loss: 0.4975 - val_accuracy: 0.8611
# Epoch 74/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0654 - accuracy: 0.9825 - val_loss: 0.5956 - val_accuracy: 0.8241
# Epoch 75/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0544 - accuracy: 0.9877 - val_loss: 0.4858 - val_accuracy: 0.8426
# Epoch 76/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0490 - accuracy: 0.9938 - val_loss: 0.6037 - val_accuracy: 0.8056
# Epoch 77/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0532 - accuracy: 0.9907 - val_loss: 0.7228 - val_accuracy: 0.7685
# Epoch 78/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0506 - accuracy: 0.9866 - val_loss: 0.5846 - val_accuracy: 0.8148
# Epoch 79/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0906 - accuracy: 0.9712 - val_loss: 0.5168 - val_accuracy: 0.8889
# Epoch 80/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0697 - accuracy: 0.9722 - val_loss: 0.6853 - val_accuracy: 0.7685
# Epoch 81/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0648 - accuracy: 0.9815 - val_loss: 0.6107 - val_accuracy: 0.8148
# Epoch 82/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0605 - accuracy: 0.9794 - val_loss: 0.5258 - val_accuracy: 0.8333
# Epoch 83/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0407 - accuracy: 0.9938 - val_loss: 0.6136 - val_accuracy: 0.8056
# Epoch 84/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0419 - accuracy: 0.9856 - val_loss: 0.6400 - val_accuracy: 0.8056
# Epoch 85/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0404 - accuracy: 0.9918 - val_loss: 0.5597 - val_accuracy: 0.8241
# Epoch 86/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0321 - accuracy: 0.9969 - val_loss: 0.5554 - val_accuracy: 0.8333
# Epoch 87/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0353 - accuracy: 0.9938 - val_loss: 0.5135 - val_accuracy: 0.8333
# Epoch 88/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0356 - accuracy: 0.9928 - val_loss: 0.5351 - val_accuracy: 0.8426
# Epoch 89/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0303 - accuracy: 0.9949 - val_loss: 0.5001 - val_accuracy: 0.8519
# Epoch 90/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0318 - accuracy: 0.9938 - val_loss: 0.4892 - val_accuracy: 0.8426
# Epoch 91/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0283 - accuracy: 0.9959 - val_loss: 0.4864 - val_accuracy: 0.8426
# Epoch 92/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0333 - accuracy: 0.9907 - val_loss: 0.5631 - val_accuracy: 0.8426
# Epoch 93/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0283 - accuracy: 0.9938 - val_loss: 0.6304 - val_accuracy: 0.8241
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0280 - accuracy: 0.9938 - val_loss: 0.5571 - val_accuracy: 0.8333
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0294 - accuracy: 0.9928 - val_loss: 0.5868 - val_accuracy: 0.8333
# Epoch 96/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0251 - accuracy: 0.9959 - val_loss: 0.6502 - val_accuracy: 0.8241
# Epoch 97/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.8333
# Epoch 98/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0196 - accuracy: 0.9979 - val_loss: 0.5553 - val_accuracy: 0.8426
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0203 - accuracy: 0.9969 - val_loss: 0.5131 - val_accuracy: 0.8426
# Epoch 100/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.0233 - accuracy: 0.9990 - val_loss: 0.5779 - val_accuracy: 0.8426
# 4/4 [==============================] - 1s 165ms/step - loss: 0.4742 - accuracy: 0.8833
# [0.474222332239151, 0.8833333253860474]
# 0.8588235294117647
# Results for fold 4
# Epoch 1/100
# 16/16 [==============================] - 39s 1s/step - loss: 1.0029 - accuracy: 0.6451 - val_loss: 0.6884 - val_accuracy: 0.5648
# Epoch 2/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.8149 - accuracy: 0.6718 - val_loss: 0.6887 - val_accuracy: 0.5926
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.7545 - accuracy: 0.6903 - val_loss: 0.6891 - val_accuracy: 0.5648
# Epoch 4/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.6982 - accuracy: 0.7099 - val_loss: 0.6912 - val_accuracy: 0.4815
# Epoch 5/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.6970 - accuracy: 0.6965 - val_loss: 0.6932 - val_accuracy: 0.4537
# Epoch 6/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6235 - accuracy: 0.7335 - val_loss: 0.6956 - val_accuracy: 0.4352
# Epoch 7/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6066 - accuracy: 0.7202 - val_loss: 0.6963 - val_accuracy: 0.4259
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5614 - accuracy: 0.7459 - val_loss: 0.6958 - val_accuracy: 0.4352
# Epoch 9/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5939 - accuracy: 0.7253 - val_loss: 0.6975 - val_accuracy: 0.4167
# Epoch 10/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5742 - accuracy: 0.7325 - val_loss: 0.6947 - val_accuracy: 0.4537
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5547 - accuracy: 0.7582 - val_loss: 0.6949 - val_accuracy: 0.4630
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5196 - accuracy: 0.7623 - val_loss: 0.6968 - val_accuracy: 0.4815
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5406 - accuracy: 0.7315 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5186 - accuracy: 0.7510 - val_loss: 0.6914 - val_accuracy: 0.5093
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4821 - accuracy: 0.7829 - val_loss: 0.6918 - val_accuracy: 0.5093
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4931 - accuracy: 0.7685 - val_loss: 0.6890 - val_accuracy: 0.5278
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4837 - accuracy: 0.7726 - val_loss: 0.6815 - val_accuracy: 0.5463
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4739 - accuracy: 0.7726 - val_loss: 0.6744 - val_accuracy: 0.5556
# Epoch 19/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4452 - accuracy: 0.7860 - val_loss: 0.6724 - val_accuracy: 0.5741
# Epoch 20/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4705 - accuracy: 0.7840 - val_loss: 0.6707 - val_accuracy: 0.5556
# Epoch 21/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4493 - accuracy: 0.7860 - val_loss: 0.6593 - val_accuracy: 0.5556
# Epoch 22/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4310 - accuracy: 0.8045 - val_loss: 0.6567 - val_accuracy: 0.5741
# Epoch 23/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3998 - accuracy: 0.8179 - val_loss: 0.6554 - val_accuracy: 0.5833
# Epoch 24/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4019 - accuracy: 0.8056 - val_loss: 0.6462 - val_accuracy: 0.5926
# Epoch 25/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3929 - accuracy: 0.8169 - val_loss: 0.6261 - val_accuracy: 0.6667
# Epoch 26/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.3755 - accuracy: 0.8467 - val_loss: 0.6259 - val_accuracy: 0.6481
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3719 - accuracy: 0.8230 - val_loss: 0.6096 - val_accuracy: 0.7037
# Epoch 28/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3507 - accuracy: 0.8385 - val_loss: 0.6159 - val_accuracy: 0.6759
# Epoch 29/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.3525 - accuracy: 0.8467 - val_loss: 0.6112 - val_accuracy: 0.6759
# Epoch 30/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3330 - accuracy: 0.8632 - val_loss: 0.6034 - val_accuracy: 0.7037
# Epoch 31/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.3150 - accuracy: 0.8673 - val_loss: 0.6304 - val_accuracy: 0.6667
# Epoch 32/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3213 - accuracy: 0.8508 - val_loss: 0.5974 - val_accuracy: 0.7130
# Epoch 33/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.2932 - accuracy: 0.8704 - val_loss: 0.5656 - val_accuracy: 0.7407
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2948 - accuracy: 0.8693 - val_loss: 0.5840 - val_accuracy: 0.7593
# Epoch 35/100
# ...
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0395 - accuracy: 0.9928 - val_loss: 0.3296 - val_accuracy: 0.9074
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0326 - accuracy: 0.9897 - val_loss: 0.3125 - val_accuracy: 0.8889
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0269 - accuracy: 0.9959 - val_loss: 0.3100 - val_accuracy: 0.8704
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0295 - accuracy: 0.9949 - val_loss: 0.3217 - val_accuracy: 0.8889
# Epoch 95/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0318 - accuracy: 0.9928 - val_loss: 0.2901 - val_accuracy: 0.9074
# Epoch 96/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0215 - accuracy: 0.9990 - val_loss: 0.2925 - val_accuracy: 0.9167
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0293 - accuracy: 0.9938 - val_loss: 0.3036 - val_accuracy: 0.8889
# Epoch 98/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0620 - accuracy: 0.9805 - val_loss: 0.5387 - val_accuracy: 0.8611
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0462 - accuracy: 0.9897 - val_loss: 0.3665 - val_accuracy: 0.8796
# Epoch 100/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0361 - accuracy: 0.9918 - val_loss: 0.3579 - val_accuracy: 0.8796
# 4/4 [==============================] - 1s 175ms/step - loss: 0.5806 - accuracy: 0.8667
# [0.5805569887161255, 0.8666666746139526]
# 0.8358413132694937
# Results for fold 10
# Epoch 1/100
# 16/16 [==============================] - 40s 1s/step - loss: 0.8270 - accuracy: 0.5021 - val_loss: 0.6825 - val_accuracy: 0.6944
# Epoch 2/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.7377 - accuracy: 0.5586 - val_loss: 0.6765 - val_accuracy: 0.7130
# Epoch 3/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6627 - accuracy: 0.6019 - val_loss: 0.6727 - val_accuracy: 0.7407
# Epoch 4/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6539 - accuracy: 0.6389 - val_loss: 0.6702 - val_accuracy: 0.7593
# Epoch 5/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6369 - accuracy: 0.6409 - val_loss: 0.6678 - val_accuracy: 0.7685
# Epoch 6/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6224 - accuracy: 0.6451 - val_loss: 0.6656 - val_accuracy: 0.7685
# Epoch 7/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.6012 - accuracy: 0.6584 - val_loss: 0.6615 - val_accuracy: 0.7685
# Epoch 8/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5763 - accuracy: 0.6903 - val_loss: 0.6582 - val_accuracy: 0.7870
# Epoch 9/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5655 - accuracy: 0.7016 - val_loss: 0.6561 - val_accuracy: 0.7778
# Epoch 10/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5754 - accuracy: 0.6893 - val_loss: 0.6532 - val_accuracy: 0.7778
# Epoch 11/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5570 - accuracy: 0.7078 - val_loss: 0.6489 - val_accuracy: 0.7870
# Epoch 12/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5313 - accuracy: 0.7233 - val_loss: 0.6435 - val_accuracy: 0.7870
# Epoch 13/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5310 - accuracy: 0.6975 - val_loss: 0.6387 - val_accuracy: 0.7870
# Epoch 14/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4885 - accuracy: 0.7541 - val_loss: 0.6319 - val_accuracy: 0.7963
# Epoch 15/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.5031 - accuracy: 0.7531 - val_loss: 0.6255 - val_accuracy: 0.7963
# Epoch 16/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4851 - accuracy: 0.7490 - val_loss: 0.6201 - val_accuracy: 0.8056
# Epoch 17/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4696 - accuracy: 0.7716 - val_loss: 0.6137 - val_accuracy: 0.7870
# Epoch 18/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4678 - accuracy: 0.7665 - val_loss: 0.6065 - val_accuracy: 0.7778
# Epoch 19/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4501 - accuracy: 0.7737 - val_loss: 0.5957 - val_accuracy: 0.7870
# Epoch 20/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4351 - accuracy: 0.7932 - val_loss: 0.5896 - val_accuracy: 0.7870
# Epoch 21/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4209 - accuracy: 0.7901 - val_loss: 0.5821 - val_accuracy: 0.7870
# Epoch 22/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3971 - accuracy: 0.8323 - val_loss: 0.5678 - val_accuracy: 0.7870
# Epoch 23/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.4132 - accuracy: 0.8117 - val_loss: 0.5579 - val_accuracy: 0.7870
# Epoch 24/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3873 - accuracy: 0.8128 - val_loss: 0.5474 - val_accuracy: 0.7963
# Epoch 25/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3843 - accuracy: 0.8200 - val_loss: 0.5322 - val_accuracy: 0.8333
# Epoch 26/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3768 - accuracy: 0.8282 - val_loss: 0.5177 - val_accuracy: 0.8241
# Epoch 27/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3654 - accuracy: 0.8333 - val_loss: 0.5031 - val_accuracy: 0.8148
# Epoch 28/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3451 - accuracy: 0.8467 - val_loss: 0.4922 - val_accuracy: 0.8333
# Epoch 29/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3356 - accuracy: 0.8426 - val_loss: 0.4817 - val_accuracy: 0.8241
# Epoch 30/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.3118 - accuracy: 0.8621 - val_loss: 0.4716 - val_accuracy: 0.8148
# Epoch 31/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2938 - accuracy: 0.8858 - val_loss: 0.4580 - val_accuracy: 0.8333
# Epoch 32/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2944 - accuracy: 0.8807 - val_loss: 0.4468 - val_accuracy: 0.8333
# Epoch 33/100
# 16/16 [==============================] - 18s 1s/step - loss: 0.2956 - accuracy: 0.8714 - val_loss: 0.4487 - val_accuracy: 0.7963
# Epoch 34/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2850 - accuracy: 0.8817 - val_loss: 0.4468 - val_accuracy: 0.7778
# Epoch 35/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2656 - accuracy: 0.8848 - val_loss: 0.4256 - val_accuracy: 0.8241
# Epoch 36/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2579 - accuracy: 0.8909 - val_loss: 0.4273 - val_accuracy: 0.8241
# Epoch 37/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2623 - accuracy: 0.8735 - val_loss: 0.4162 - val_accuracy: 0.8241
# Epoch 38/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2392 - accuracy: 0.9012 - val_loss: 0.4198 - val_accuracy: 0.8241
# Epoch 39/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2185 - accuracy: 0.9167 - val_loss: 0.4213 - val_accuracy: 0.8241
# Epoch 40/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2291 - accuracy: 0.9064 - val_loss: 0.4414 - val_accuracy: 0.8241
# Epoch 41/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.2175 - accuracy: 0.9228 - val_loss: 0.4277 - val_accuracy: 0.8241
# Epoch 42/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1995 - accuracy: 0.9239 - val_loss: 0.4337 - val_accuracy: 0.8241
# Epoch 43/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1973 - accuracy: 0.9095 - val_loss: 0.4390 - val_accuracy: 0.8333
# Epoch 44/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1821 - accuracy: 0.9259 - val_loss: 0.4065 - val_accuracy: 0.8426
# Epoch 45/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1797 - accuracy: 0.9311 - val_loss: 0.4459 - val_accuracy: 0.8333
# Epoch 46/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1633 - accuracy: 0.9414 - val_loss: 0.4135 - val_accuracy: 0.8333
# Epoch 47/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1533 - accuracy: 0.9455 - val_loss: 0.4611 - val_accuracy: 0.8333
# Epoch 48/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1444 - accuracy: 0.9362 - val_loss: 0.4323 - val_accuracy: 0.8241
# Epoch 49/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1390 - accuracy: 0.9486 - val_loss: 0.4567 - val_accuracy: 0.8333
# Epoch 50/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1271 - accuracy: 0.9599 - val_loss: 0.4544 - val_accuracy: 0.8426
# Epoch 51/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1200 - accuracy: 0.9578 - val_loss: 0.4652 - val_accuracy: 0.8426
# Epoch 52/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1183 - accuracy: 0.9650 - val_loss: 0.4491 - val_accuracy: 0.8426
# Epoch 53/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1239 - accuracy: 0.9578 - val_loss: 0.4544 - val_accuracy: 0.8426
# Epoch 54/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1064 - accuracy: 0.9640 - val_loss: 0.4477 - val_accuracy: 0.8611
# Epoch 55/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1042 - accuracy: 0.9609 - val_loss: 0.4680 - val_accuracy: 0.8426
# Epoch 56/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0979 - accuracy: 0.9681 - val_loss: 0.4662 - val_accuracy: 0.8426
# Epoch 57/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0907 - accuracy: 0.9733 - val_loss: 0.4740 - val_accuracy: 0.8426
# Epoch 58/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1038 - accuracy: 0.9671 - val_loss: 0.4802 - val_accuracy: 0.8519
# Epoch 59/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.1044 - accuracy: 0.9702 - val_loss: 0.4733 - val_accuracy: 0.8519
# Epoch 60/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0829 - accuracy: 0.9691 - val_loss: 0.5170 - val_accuracy: 0.8519
# Epoch 61/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0839 - accuracy: 0.9753 - val_loss: 0.4996 - val_accuracy: 0.8519
# Epoch 62/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0777 - accuracy: 0.9784 - val_loss: 0.5136 - val_accuracy: 0.8333
# Epoch 63/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0776 - accuracy: 0.9763 - val_loss: 0.5040 - val_accuracy: 0.8519
# Epoch 64/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0665 - accuracy: 0.9856 - val_loss: 0.5262 - val_accuracy: 0.8426
# Epoch 65/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0672 - accuracy: 0.9846 - val_loss: 0.5002 - val_accuracy: 0.8519
# Epoch 66/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0602 - accuracy: 0.9887 - val_loss: 0.5423 - val_accuracy: 0.8519
# Epoch 67/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0717 - accuracy: 0.9815 - val_loss: 0.5104 - val_accuracy: 0.8519
# Epoch 68/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0612 - accuracy: 0.9825 - val_loss: 0.5265 - val_accuracy: 0.8611
# Epoch 69/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0638 - accuracy: 0.9805 - val_loss: 0.5546 - val_accuracy: 0.8426
# Epoch 70/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0526 - accuracy: 0.9887 - val_loss: 0.5173 - val_accuracy: 0.8519
# Epoch 71/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0577 - accuracy: 0.9856 - val_loss: 0.5440 - val_accuracy: 0.8426
# Epoch 72/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0592 - accuracy: 0.9866 - val_loss: 0.5588 - val_accuracy: 0.8519
# Epoch 73/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0501 - accuracy: 0.9856 - val_loss: 0.5261 - val_accuracy: 0.8611
# Epoch 74/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0479 - accuracy: 0.9887 - val_loss: 0.5184 - val_accuracy: 0.8611
# Epoch 75/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0509 - accuracy: 0.9825 - val_loss: 0.5304 - val_accuracy: 0.8426
# Epoch 76/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0469 - accuracy: 0.9856 - val_loss: 0.5686 - val_accuracy: 0.8611
# Epoch 77/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0466 - accuracy: 0.9887 - val_loss: 0.5997 - val_accuracy: 0.8519
# Epoch 78/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0557 - accuracy: 0.9846 - val_loss: 0.5560 - val_accuracy: 0.8611
# Epoch 79/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0402 - accuracy: 0.9928 - val_loss: 0.5638 - val_accuracy: 0.8611
# Epoch 80/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0464 - accuracy: 0.9918 - val_loss: 0.5695 - val_accuracy: 0.8611
# Epoch 81/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0485 - accuracy: 0.9846 - val_loss: 0.5911 - val_accuracy: 0.8426
# Epoch 82/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0451 - accuracy: 0.9846 - val_loss: 0.5900 - val_accuracy: 0.8519
# Epoch 83/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0435 - accuracy: 0.9897 - val_loss: 0.6203 - val_accuracy: 0.8426
# Epoch 84/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0398 - accuracy: 0.9866 - val_loss: 0.6626 - val_accuracy: 0.8611
# Epoch 85/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0343 - accuracy: 0.9938 - val_loss: 0.6613 - val_accuracy: 0.8704
# Epoch 86/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0345 - accuracy: 0.9918 - val_loss: 0.5852 - val_accuracy: 0.8426
# Epoch 87/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0277 - accuracy: 0.9969 - val_loss: 0.5564 - val_accuracy: 0.8704
# Epoch 88/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0429 - accuracy: 0.9907 - val_loss: 0.5287 - val_accuracy: 0.8611
# Epoch 89/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0258 - accuracy: 0.9979 - val_loss: 0.5279 - val_accuracy: 0.8519
# Epoch 90/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0205 - accuracy: 0.9979 - val_loss: 0.5324 - val_accuracy: 0.8519
# Epoch 91/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0323 - accuracy: 0.9938 - val_loss: 0.6236 - val_accuracy: 0.8426
# Epoch 92/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0211 - accuracy: 0.9990 - val_loss: 0.5735 - val_accuracy: 0.8519
# Epoch 93/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0260 - accuracy: 0.9938 - val_loss: 0.5383 - val_accuracy: 0.8704
# Epoch 94/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0180 - accuracy: 0.9979 - val_loss: 0.5794 - val_accuracy: 0.8519
# Epoch 95/100
# 16/16 [==============================] - 27s 2s/step - loss: 0.0294 - accuracy: 0.9918 - val_loss: 0.5343 - val_accuracy: 0.8519
# Epoch 96/100
# 16/16 [==============================] - 31s 2s/step - loss: 0.0236 - accuracy: 0.9969 - val_loss: 0.6215 - val_accuracy: 0.8611
# Epoch 97/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0165 - accuracy: 0.9990 - val_loss: 0.6186 - val_accuracy: 0.8704
# Epoch 98/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0207 - accuracy: 0.9969 - val_loss: 0.6170 - val_accuracy: 0.8796
# Epoch 99/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0181 - accuracy: 0.9969 - val_loss: 0.6159 - val_accuracy: 0.8519
# Epoch 100/100
# 16/16 [==============================] - 19s 1s/step - loss: 0.0212 - accuracy: 0.9969 - val_loss: 0.5930 - val_accuracy: 0.8611
# 4/4 [==============================] - 1s 197ms/step - loss: 0.5644 - accuracy: 0.8750
# [0.5644000768661499, 0.875]
# 0.844707100336468

# %%
acrc = np.array(val_res['accuracy']).mean(axis=0)
f1scr = np.array(val_res['f1_score']).mean(axis=0)
print("Accuracy  : {}".format(acrc[1]))
print("F1_Score  : {}".format(f1scr))
cmatrix = np.array(val_res['confusion_matrix']).mean(axis=0)
c_matrix = cmatrix/np.sum(cmatrix, axis=1).reshape(2,1)
import seaborn as sns
figure = plt.figure(figsize=(9, 9))
sns.heatmap(c_matrix, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Accuracy  : 0.8625000059604645
# F1_Score  : 0.8326126310134899
