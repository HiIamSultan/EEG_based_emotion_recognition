# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import pickle as pkl
from tensorflow import keras
import tensorflow.keras.backend as K
from keras.models import Sequential,Model
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Flatten, Input, Reshape, BatchNormalization, Bidirectional, LSTM, Multiply, Activation, Normalization, TimeDistributed
from keras.layers import Conv3D, Conv2D, Conv1D, MaxPool3D, MaxPool2D, MaxPool1D, AvgPool3D, AvgPool2D, AvgPool1D, GlobalMaxPool3D, Attention, Subtract
from keras.layers import GlobalMaxPool2D, GlobalMaxPool1D, SpatialDropout3D, SpatialDropout2D, SpatialDropout1D, GlobalAvgPool3D, MultiHeadAttention
from keras.layers import GlobalAvgPool2D, GlobalAvgPool1D, SeparableConv2D, SeparableConv1D, Add, Concatenate, LeakyReLU, ELU, Activation, PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from keras.utils import np_utils
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight
import gc

# %% [markdown]
# # **Data Loading**

# %%
from google.colab import drive
drive.mount('/content/drive/')
gc.collect()
# Out:
# Mounted at /content/drive/
# 81

# %%
input_path='/content/drive/MyDrive/data_preprocessed_python/'

# %%
def baseline_remove(XR):
  XT = XR[:, 384:]
  XB_ = (XR[:, :1*128] + XR[:, 1*128:2*128] + XR[:, 2*128:3*128])/3.0
  for i in range(60):
    XT[:, i*128:(i+1)*128] = XT[:, i*128:(i+1)*128] - XB_
  return XT

# %%
new_channels = [0,1,18,2,3,5,4,23,6,7,9,8,15,10,11,12,14,13,
 16,17,18,19,20,22,21,23,24,25,27,26,15,28,29,30,14,31]

# %%
eeg_signal = []
valence = []
arousal = []
window_size = 256
no_channels = 32
no_new_channels = len(new_channels)
no_videos = 40
Trsld = 5

for person in range(5,6):
  print('Person No.' + str(person))
  
  
  # EEG files address
  if person < 10 :
    address = input_path+'s0'+str(person)+'.dat'
  else :
    address = input_path+'s'+str(person)+'.dat'

  with open(address, 'rb') as file:
    data = pkl.load(file, encoding = 'latin1')

  eeg = data['data']
  label = data['labels']
  
  # Assigning classes
  label[label<Trsld] = 0
  label[label>=Trsld] = 1

  val = label.T[0] # Valence label
  aro = label.T[1] # Arousal label

  del data, label
  # Iterating through 40 vidoes/trials
  for i in range(no_videos):
    sig = eeg[i][:no_channels, :]
    sig = baseline_remove(sig)
    temp = []
    for j in new_channels:
      temp.append(sig[j, :])
    sig = np.reshape(temp,[no_new_channels,-1])
    # Segmenting into 2 seconds (256 timesteps) windows without overlap
    start = 0
    while start + window_size <=sig.shape[1]:
      eeg_signal.append(sig[:, start:start+window_size].T)
      valence.append(val[i])
      arousal.append(aro[i])
      start += window_size 
  del eeg, val, aro, sig
eeg_signal = np.reshape(eeg_signal,[-1,window_size,no_new_channels])
data = np.asarray(eeg_signal, dtype = np.float32) # Using 32 bit floating point value to save memory
del eeg_signal
valence = np.asarray(valence, dtype = np.int8)
arousal = np.asarray(arousal, dtype = np.int8)

print(data.shape)
print(valence.shape, valence[valence == 0].shape, valence[valence == 1].shape)
print(arousal.shape, arousal[arousal == 0].shape, arousal[arousal == 1].shape)

valence = np_utils.to_categorical(valence)
arousal = np_utils.to_categorical(arousal)
gc.collect()
# Out:
# Person No.5
# (1200, 256, 36)
# (1200,) (480,) (720,)
# (1200,) (630,) (570,)
# 0

# %%
def simple_2D_CNN(x): 
  x = BatchNormalization()(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=True))(x)
  x = Bidirectional(LSTM(32, return_sequences=False))(x)
  x = BatchNormalization()(x)
  x = Dropout(0.4)(x)
  x = Dense(32, activation='relu')(x)
  x = Dropout(0.1)(x)
  x = Dense(2, activation='softmax')(x)
  return x

def get_model(): 
  input_shape = (data.shape[1], data.shape[2]) 
  a = Input(input_shape) 
  out = simple_2D_CNN(a) 
  model = Model(a, out) 
  opt = keras.optimizers.Adam(learning_rate=1e-04) 
  model.compile(loss=keras.losses.categorical_crossentropy, metrics=["accuracy"], optimizer=opt) 
  return model 
model = get_model() 
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 36)]         0
#
#  batch_normalization (BatchN  (None, 256, 36)          144
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 256, 64)          17664
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 256, 64)          24832
#  nal)
#
#  bidirectional_4 (Bidirectio  (None, 64)               24832
#  nal)
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 119,538
# Trainable params: 119,338
# Non-trainable params: 200
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=False)

# %%
batch_size = 64
epochs = 100
kfold = KFold(n_splits=10, random_state=1, shuffle=True)
gc.collect()
# Out:
# 37895

# %%
def call_class_weights(yt):
  y_integers = np.argmax(yt, axis=1)
  class_weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(y_integers), y = y_integers)
  d_class_weights = dict(enumerate(class_weights))
  return d_class_weights

# %% [markdown]
# # **Arousal**

# %%
#arousal
X_train, x_test, Y_train, y_test = train_test_split(data,arousal, test_size=0.1, random_state=4)
print(X_train.shape,x_test.shape,Y_train.shape,y_test.shape)
# Out:
# (1080, 256, 36) (120, 256, 36) (1080, 2) (120, 2)

# %%
val_res = {'accuracy': [], 'f1_score': [], 'confusion_matrix': []}
foldNum=0
#model = get_model()
for train_index, val_index in kfold.split(X_train, Y_train):
  foldNum = foldNum + 1
  model = get_model()
  print("Results for fold",foldNum)
  x_train, x_val = X_train[train_index], X_train[val_index]
  y_train, y_val = Y_train[train_index], Y_train[val_index]
  class_weight = call_class_weights(y_train)
  history = model.fit(x_train, y_train, epochs=epochs, class_weight=class_weight, batch_size=batch_size, verbose=1, validation_data=(x_val, y_val),shuffle=True)
  acc = model.evaluate(x_test, y_test)
  print(acc)
  val_res['accuracy'].append(acc)
  pred = model.predict(x_test)
  f1scr = f1_score(y_test.argmax(1), pred.argmax(1), average='macro')
  print(f1scr)
  pd.DataFrame(history.history).plot(figsize=(8,5))
  plt.show()
  val_res['f1_score'].append(f1scr)
  val_res['confusion_matrix'].append(confusion_matrix(y_test.argmax(1), pred.argmax(1)))
  gc.collect() # Garbage collecter
  del x_train, x_val, y_train, y_val, acc, f1scr
  gc.collect()
# Out:
# Results for fold 1
# Epoch 1/100
# 16/16 [==============================] - 64s 2s/step - loss: 0.8481 - accuracy: 0.5422 - val_loss: 0.6839 - val_accuracy: 0.5648
# Epoch 2/100
# 16/16 [==============================] - 23s 1s/step - loss: 0
100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3082 - accuracy: 0.8796 - val_loss: 0.5256 - val_accuracy: 0.7407
# Epoch 32/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3145 - accuracy: 0.8611 - val_loss: 0.5258 - val_accuracy: 0.7222
# Epoch 33/100
# 16/16 [==============================] - 22s 1s/step - loss: 0.3095 - accuracy: 0.8714 - val_loss: 0.5082 - val_accuracy: 0.7500
# Epoch 34/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.2979 - accuracy: 0.8683 - val_loss: 0.4390 - val_accuracy: 0.8241
# Epoch 35/100
# ...
# Epoch 91/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0833 - accuracy: 0.9805 - val_loss: 0.3916 - val_accuracy: 0.8426
# Epoch 92/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0854 - accuracy: 0.9722 - val_loss: 0.3986 - val_accuracy: 0.8056
# Epoch 93/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0840 - accuracy: 0.9733 - val_loss: 0.3980 - val_accuracy: 0.8426
# Epoch 94/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0960 - accuracy: 0.9691 - val_loss: 0.3763 - val_accuracy: 0.8519
# Epoch 95/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0837 - accuracy: 0.9722 - val_loss: 0.4726 - val_accuracy: 0.8426
# Epoch 96/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0929 - accuracy: 0.9671 - val_loss: 0.3705 - val_accuracy: 0.8426
# Epoch 97/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0767 - accuracy: 0.9784 - val_loss: 0.3633 - val_accuracy: 0.8611
# Epoch 98/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0760 - accuracy: 0.9753 - val_loss: 0.3478 - val_accuracy: 0.8426
# Epoch 99/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0601 - accuracy: 0.9866 - val_loss: 0.4114 - val_accuracy: 0.8611
# Epoch 100/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0752 - accuracy: 0.9763 - val_loss: 0.3803 - val_accuracy: 0.8241
# 4/4 [==============================] - 1s 186ms/step - loss: 0.3208 - accuracy: 0.8667
# [0.32076582312583923, 0.8666666746139526]
# 0.8665183537263625
# Results for fold 10
# Epoch 1/100
# 16/16 [==============================] - 44s 2s/step - loss: 0.8345 - accuracy: 0.4949 - val_loss: 0.6909 - val_accuracy: 0.5278
# Epoch 2/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.7523 - accuracy: 0.5278 - val_loss: 0.6873 - val_accuracy: 0.7037
# Epoch 3/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.7071 - accuracy: 0.5514 - val_loss: 0.6847 - val_accuracy: 0.6944
# Epoch 4/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.6613 - accuracy: 0.6142 - val_loss: 0.6822 - val_accuracy: 0.6759
# Epoch 5/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.6345 - accuracy: 0.5947 - val_loss: 0.6797 - val_accuracy: 0.6204
# Epoch 6/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.6121 - accuracy: 0.6214 - val_loss: 0.6775 - val_accuracy: 0.6296
# Epoch 7/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.6009 - accuracy: 0.6667 - val_loss: 0.6750 - val_accuracy: 0.6204
# Epoch 8/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5928 - accuracy: 0.6656 - val_loss: 0.6724 - val_accuracy: 0.6296
# Epoch 9/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.5785 - accuracy: 0.6944 - val_loss: 0.6694 - val_accuracy: 0.6296
# Epoch 10/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.5580 - accuracy: 0.7099 - val_loss: 0.6655 - val_accuracy: 0.6296
# Epoch 11/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5440 - accuracy: 0.7191 - val_loss: 0.6620 - val_accuracy: 0.6389
# Epoch 12/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5201 - accuracy: 0.7428 - val_loss: 0.6581 - val_accuracy: 0.6574
# Epoch 13/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5200 - accuracy: 0.7377 - val_loss: 0.6534 - val_accuracy: 0.6759
# Epoch 14/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5121 - accuracy: 0.7572 - val_loss: 0.6493 - val_accuracy: 0.6852
# Epoch 15/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.5058 - accuracy: 0.7706 - val_loss: 0.6463 - val_accuracy: 0.6852
# Epoch 16/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4944 - accuracy: 0.7716 - val_loss: 0.6413 - val_accuracy: 0.7130
# Epoch 17/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4645 - accuracy: 0.7747 - val_loss: 0.6347 - val_accuracy: 0.7407
# Epoch 18/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.4960 - accuracy: 0.7634 - val_loss: 0.6289 - val_accuracy: 0.7315
# Epoch 19/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.4687 - accuracy: 0.7685 - val_loss: 0.6236 - val_accuracy: 0.7685
# Epoch 20/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.4534 - accuracy: 0.7891 - val_loss: 0.6154 - val_accuracy: 0.7685
# Epoch 21/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4420 - accuracy: 0.8200 - val_loss: 0.6088 - val_accuracy: 0.7778
# Epoch 22/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4345 - accuracy: 0.8076 - val_loss: 0.6003 - val_accuracy: 0.7500
# Epoch 23/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4442 - accuracy: 0.7942 - val_loss: 0.5913 - val_accuracy: 0.7593
# Epoch 24/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.4158 - accuracy: 0.8128 - val_loss: 0.5871 - val_accuracy: 0.7593
# Epoch 25/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.4212 - accuracy: 0.8076 - val_loss: 0.5800 - val_accuracy: 0.7593
# Epoch 26/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.4017 - accuracy: 0.8210 - val_loss: 0.5666 - val_accuracy: 0.7778
# Epoch 27/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3922 - accuracy: 0.8261 - val_loss: 0.5537 - val_accuracy: 0.8148
# Epoch 28/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3957 - accuracy: 0.8189 - val_loss: 0.5419 - val_accuracy: 0.7778
# Epoch 29/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3624 - accuracy: 0.8519 - val_loss: 0.5335 - val_accuracy: 0.7685
# Epoch 30/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3767 - accuracy: 0.8313 - val_loss: 0.5141 - val_accuracy: 0.7870
# Epoch 31/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3491 - accuracy: 0.8457 - val_loss: 0.5067 - val_accuracy: 0.7963
# Epoch 32/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3498 - accuracy: 0.8467 - val_loss: 0.4972 - val_accuracy: 0.7963
# Epoch 33/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3402 - accuracy: 0.8519 - val_loss: 0.4833 - val_accuracy: 0.7963
# Epoch 34/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3173 - accuracy: 0.8714 - val_loss: 0.4609 - val_accuracy: 0.8056
# Epoch 35/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3182 - accuracy: 0.8704 - val_loss: 0.4562 - val_accuracy: 0.8148
# Epoch 36/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.3166 - accuracy: 0.8755 - val_loss: 0.4459 - val_accuracy: 0.8519
# Epoch 37/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3119 - accuracy: 0.8765 - val_loss: 0.4498 - val_accuracy: 0.8333
# Epoch 38/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.3020 - accuracy: 0.8817 - val_loss: 0.4386 - val_accuracy: 0.8333
# Epoch 39/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2673 - accuracy: 0.8940 - val_loss: 0.4263 - val_accuracy: 0.8519
# Epoch 40/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.2806 - accuracy: 0.8879 - val_loss: 0.4309 - val_accuracy: 0.8333
# Epoch 41/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.2662 - accuracy: 0.9043 - val_loss: 0.4337 - val_accuracy: 0.8611
# Epoch 42/100
# 16/16 [==============================] - 22s 1s/step - loss: 0.2673 - accuracy: 0.9002 - val_loss: 0.4050 - val_accuracy: 0.8704
# Epoch 43/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2448 - accuracy: 0.9074 - val_loss: 0.4024 - val_accuracy: 0.8796
# Epoch 44/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2313 - accuracy: 0.9218 - val_loss: 0.4187 - val_accuracy: 0.8704
# Epoch 45/100
# 16/16 [==============================] - 22s 1s/step - loss: 0.2325 - accuracy: 0.9156 - val_loss: 0.3983 - val_accuracy: 0.8981
# Epoch 46/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2183 - accuracy: 0.9259 - val_loss: 0.4075 - val_accuracy: 0.8796
# Epoch 47/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2218 - accuracy: 0.9115 - val_loss: 0.3980 - val_accuracy: 0.8796
# Epoch 48/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2115 - accuracy: 0.9187 - val_loss: 0.4357 - val_accuracy: 0.8426
# Epoch 49/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.2155 - accuracy: 0.9208 - val_loss: 0.4068 - val_accuracy: 0.8796
# Epoch 50/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1928 - accuracy: 0.9280 - val_loss: 0.4551 - val_accuracy: 0.8333
# Epoch 51/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1740 - accuracy: 0.9403 - val_loss: 0.4344 - val_accuracy: 0.8889
# Epoch 52/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1996 - accuracy: 0.9177 - val_loss: 0.4207 - val_accuracy: 0.8704
# Epoch 53/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1779 - accuracy: 0.9321 - val_loss: 0.4361 - val_accuracy: 0.8981
# Epoch 54/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1672 - accuracy: 0.9372 - val_loss: 0.4550 - val_accuracy: 0.8611
# Epoch 55/100
# 16/16 [==============================] - 22s 1s/step - loss: 0.1735 - accuracy: 0.9331 - val_loss: 0.4222 - val_accuracy: 0.8796
# Epoch 56/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1577 - accuracy: 0.9342 - val_loss: 0.4584 - val_accuracy: 0.8981
# Epoch 57/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1582 - accuracy: 0.9516 - val_loss: 0.4511 - val_accuracy: 0.8611
# Epoch 58/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1387 - accuracy: 0.9578 - val_loss: 0.4312 - val_accuracy: 0.8704
# Epoch 59/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1546 - accuracy: 0.9424 - val_loss: 0.4768 - val_accuracy: 0.8611
# Epoch 60/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1397 - accuracy: 0.9537 - val_loss: 0.4757 - val_accuracy: 0.8611
# Epoch 61/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1374 - accuracy: 0.9558 - val_loss: 0.4444 - val_accuracy: 0.8981
# Epoch 62/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1183 - accuracy: 0.9619 - val_loss: 0.4533 - val_accuracy: 0.8704
# Epoch 63/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1167 - accuracy: 0.9609 - val_loss: 0.4591 - val_accuracy: 0.8704
# Epoch 64/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1121 - accuracy: 0.9660 - val_loss: 0.4596 - val_accuracy: 0.9074
# Epoch 65/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1098 - accuracy: 0.9630 - val_loss: 0.4374 - val_accuracy: 0.8704
# Epoch 66/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1077 - accuracy: 0.9671 - val_loss: 0.4358 - val_accuracy: 0.8981
# Epoch 67/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1266 - accuracy: 0.9496 - val_loss: 0.4942 - val_accuracy: 0.8519
# Epoch 68/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1058 - accuracy: 0.9681 - val_loss: 0.5270 - val_accuracy: 0.8611
# Epoch 69/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0924 - accuracy: 0.9733 - val_loss: 0.5391 - val_accuracy: 0.8611
# Epoch 70/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.1062 - accuracy: 0.9640 - val_loss: 0.5428 - val_accuracy: 0.8426
# Epoch 71/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1485 - accuracy: 0.9403 - val_loss: 0.6316 - val_accuracy: 0.8333
# Epoch 72/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1104 - accuracy: 0.9578 - val_loss: 0.7073 - val_accuracy: 0.7963
# Epoch 73/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.1046 - accuracy: 0.9630 - val_loss: 0.4997 - val_accuracy: 0.8519
# Epoch 74/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0880 - accuracy: 0.9763 - val_loss: 0.4954 - val_accuracy: 0.8889
# Epoch 75/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0864 - accuracy: 0.9743 - val_loss: 0.5001 - val_accuracy: 0.8611
# Epoch 76/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0809 - accuracy: 0.9784 - val_loss: 0.4912 - val_accuracy: 0.8981
# Epoch 77/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0698 - accuracy: 0.9784 - val_loss: 0.4795 - val_accuracy: 0.8704
# Epoch 78/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0790 - accuracy: 0.9712 - val_loss: 0.4870 - val_accuracy: 0.8611
# Epoch 79/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0711 - accuracy: 0.9733 - val_loss: 0.4973 - val_accuracy: 0.8333
# Epoch 80/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0711 - accuracy: 0.9784 - val_loss: 0.4850 - val_accuracy: 0.8519
# Epoch 81/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0589 - accuracy: 0.9846 - val_loss: 0.5493 - val_accuracy: 0.8796
# Epoch 82/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0575 - accuracy: 0.9856 - val_loss: 0.5131 - val_accuracy: 0.8519
# Epoch 83/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0573 - accuracy: 0.9794 - val_loss: 0.5728 - val_accuracy: 0.8611
# Epoch 84/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0721 - accuracy: 0.9712 - val_loss: 0.5114 - val_accuracy: 0.8704
# Epoch 85/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0615 - accuracy: 0.9835 - val_loss: 0.5475 - val_accuracy: 0.8519
# Epoch 86/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0602 - accuracy: 0.9794 - val_loss: 0.5609 - val_accuracy: 0.8796
# Epoch 87/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0613 - accuracy: 0.9805 - val_loss: 0.6427 - val_accuracy: 0.8333
# Epoch 88/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0548 - accuracy: 0.9856 - val_loss: 0.5193 - val_accuracy: 0.8704
# Epoch 89/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0522 - accuracy: 0.9825 - val_loss: 0.5626 - val_accuracy: 0.8704
# Epoch 90/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0632 - accuracy: 0.9825 - val_loss: 0.5495 - val_accuracy: 0.8704
# Epoch 91/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0525 - accuracy: 0.9835 - val_loss: 0.5379 - val_accuracy: 0.8333
# Epoch 92/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0429 - accuracy: 0.9907 - val_loss: 0.5973 - val_accuracy: 0.8426
# Epoch 93/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0646 - accuracy: 0.9784 - val_loss: 0.5606 - val_accuracy: 0.8611
# Epoch 94/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0458 - accuracy: 0.9887 - val_loss: 0.5203 - val_accuracy: 0.8611
# Epoch 95/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0593 - accuracy: 0.9825 - val_loss: 0.5877 - val_accuracy: 0.8704
# Epoch 96/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0411 - accuracy: 0.9887 - val_loss: 0.5400 - val_accuracy: 0.8611
# Epoch 97/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0631 - accuracy: 0.9794 - val_loss: 0.5758 - val_accuracy: 0.8611
# Epoch 98/100
# 16/16 [==============================] - 21s 1s/step - loss: 0.0817 - accuracy: 0.9712 - val_loss: 0.5299 - val_accuracy: 0.8704
# Epoch 99/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0425 - accuracy: 0.9877 - val_loss: 0.5451 - val_accuracy: 0.8704
# Epoch 100/100
# 16/16 [==============================] - 20s 1s/step - loss: 0.0527 - accuracy: 0.9846 - val_loss: 0.5307 - val_accuracy: 0.8796
# 4/4 [==============================] - 1s 174ms/step - loss: 0.2945 - accuracy: 0.9167
# [0.29453128576278687, 0.9166666865348816]
# 0.9162946428571428

# %%
acrc = np.array(val_res['accuracy']).mean(axis=0)
f1scr = np.array(val_res['f1_score']).mean(axis=0)
print("Accuracy  : {}".format(acrc[1]))
print("F1_Score  : {}".format(f1scr))
cmatrix = np.array(val_res['confusion_matrix']).mean(axis=0)
c_matrix = cmatrix/np.sum(cmatrix, axis=1).reshape(2,1)
import seaborn as sns
figure = plt.figure(figsize=(9, 9))
sns.heatmap(c_matrix, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Accuracy  : 0.8791666626930237
# F1_Score  : 0.8782178227731355
